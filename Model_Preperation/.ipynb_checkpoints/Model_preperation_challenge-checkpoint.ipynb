# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from scipy.stats import zscore
import seaborn as sns
from scipy.stats import jarque_bera
from scipy.stats import normaltest
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from scipy.stats import boxcox
from skew_autotransform import skew_autotransform
import scipy.stats as stats

# %%
## load data

postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'lifeexpectancy'
table_name = 'lifeexpectancy'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

life_df = pd.read_sql_query('select * from lifeexpectancy',con=engine)

# no need for an open connection, 
# as we're only doing a single query
engine.dispose()

# %%
life_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Status                             2938 non-null object
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
#  HIV/AIDS                          2938 non-null float64
# GDP                                2490 non-null float64
# Population                         2286 non-null float64
#  thinness  1-19 years              2904 non-null float64
#  thinness 5-9 years                2904 non-null float64
# Income composition of resources    2771 non-null float64
# Schooling                          2775 non-null float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.0+ KB

# %%
# strip spaces from column names
life_df.columns = life_df.columns.str.strip()

# %%
# copy of dataframe to be used in section 4
life_df_copy = life_df.copy()

# summary statistics of all features
life_df.describe(include='all')
# Out:
#              Country         Year      Status  Life expectancy  \
# count           2938  2938.000000        2938      2928.000000
# unique           193          NaN           2              NaN
# top     Saudi Arabia          NaN  Developing              NaN
# freq              16          NaN        2426              NaN
# mean             NaN  2007.518720         NaN        69.224932
# std              NaN     4.613841         NaN         9.523867
# min              NaN  2000.000000         NaN        36.300000
# 25%              NaN  2004.000000         NaN        63.100000
# 50%              NaN  2008.000000         NaN        72.100000
# 75%              NaN  2012.000000         NaN        75.700000
# max              NaN  2015.000000         NaN        89.000000
#
#         Adult Mortality  infant deaths      Alcohol  percentage expenditure  \
# count       2928.000000    2938.000000  2744.000000             2938.000000
# unique              NaN            NaN          NaN                     NaN
# top                 NaN            NaN          NaN                     NaN
# freq                NaN            NaN          NaN                     NaN
# mean         164.796448      30.303948     4.602861              738.251295
# std          124.292079     117.926501     4.052413             1987.914858
# min            1.000000       0.000000     0.010000                0.000000
# 25%           74.000000       0.000000     0.877500                4.685343
# 50%          144.000000       3.000000     3.755000               64.912906
# 75%          228.000000      22.000000     7.702500              441.534144
# max          723.000000    1800.000000    17.870000            19479.911610
#
#         Hepatitis B        Measles  ...        Polio  Total expenditure  \
# count   2385.000000    2938.000000  ...  2919.000000         2712.00000
# unique          NaN            NaN  ...          NaN                NaN
# top             NaN            NaN  ...          NaN                NaN
# freq            NaN            NaN  ...          NaN                NaN
# mean      80.940461    2419.592240  ...    82.550188            5.93819
# std       25.070016   11467.272489  ...    23.428046            2.49832
# min        1.000000       0.000000  ...     3.000000            0.37000
# 25%       77.000000       0.000000  ...    78.000000            4.26000
# 50%       92.000000      17.000000  ...    93.000000            5.75500
# 75%       97.000000     360.250000  ...    97.000000            7.49250
# max       99.000000  212183.000000  ...    99.000000           17.60000
#
#          Diphtheria     HIV/AIDS            GDP    Population  \
# count   2919.000000  2938.000000    2490.000000  2.286000e+03
# unique          NaN          NaN            NaN           NaN
# top             NaN          NaN            NaN           NaN
# freq            NaN          NaN            NaN           NaN
# mean      82.324084     1.742103    7483.158469  1.275338e+07
# std       23.716912     5.077785   14270.169342  6.101210e+07
# min        2.000000     0.100000       1.681350  3.400000e+01
# 25%       78.000000     0.100000     463.935626  1.957932e+05
# 50%       93.000000     0.100000    1766.947595  1.386542e+06
# 75%       97.000000     0.800000    5910.806335  7.420359e+06
# max       99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years  thinness 5-9 years  \
# count            2904.000000         2904.000000
# unique                   NaN                 NaN
# top                      NaN                 NaN
# freq                     NaN                 NaN
# mean                4.839704            4.870317
# std                 4.420195            4.508882
# min                 0.100000            0.100000
# 25%                 1.600000            1.500000
# 50%                 3.300000            3.300000
# 75%                 7.200000            7.200000
# max                27.700000           28.600000
#
#         Income composition of resources    Schooling
# count                       2771.000000  2775.000000
# unique                              NaN          NaN
# top                                 NaN          NaN
# freq                                NaN          NaN
# mean                           0.627551    11.992793
# std                            0.210904     3.358920
# min                            0.000000     0.000000
# 25%                            0.493000    10.100000
# 50%                            0.677000    12.300000
# 75%                            0.779000    14.300000
# max                            0.948000    20.700000
#
# [11 rows x 22 columns]

# %% [markdown]
# ***
# # Data preperation
# ## 1. Handling missing data

# %%
## percent of empty entries in each column
life_df.isnull().sum()/life_df.shape[0]*100
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
# BMI                                 1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
# HIV/AIDS                            0.000000
# GDP                                15.248468
# Population                         22.191967
# thinness  1-19 years                1.157250
# thinness 5-9 years                  1.157250
# Income composition of resources     5.684139
# Schooling                           5.547992
# dtype: float64

# %%
## Are there rows with multiple missing entries?
na_count = life_df.isnull().sum(axis=1)
plt.hist(na_count)
plt.xlabel("Num of NA's/ row")
plt.show()

# %%
## Eliminate rows with more than 3 na's

# save na's per column stats
size = life_df.shape[0]
before_drop = (life_df.isnull().sum()/size*100).values

# subset
life_df = life_df[na_count <= 2]
print('{} ({:.3}%) rows were dropped\n'.format(size-life_df.shape[0], (size-life_df.shape[0])/size*100))

# print percent of empty cells before and after dropping rows
after_drop = (life_df.isnull().sum()/size*100).values
drop_ind = life_df.columns
print('{0:<32}      {1:<12}      {2:<12}'.format('', 'before', 'after')) 
for row in zip(drop_ind, before_drop, after_drop):
    print('{0:<32}      {1:<15.3}      {2:<15.3}'.format(*row))
# Out:
# 272 (9.26%) rows were dropped
#
#                                       before            after
# Country                               0.0                  0.0
# Year                                  0.0                  0.0
# Status                                0.0                  0.0
# Life expectancy                       0.34                 0.0
# Adult Mortality                       0.34                 0.0
# infant deaths                         0.0                  0.0
# Alcohol                               6.6                  4.36
# percentage expenditure                0.0                  0.0
# Hepatitis B                           18.8                 15.3
# Measles                               0.0                  0.0
# BMI                                   1.16                 0.0
# under-five deaths                     0.0                  0.0
# Polio                                 0.647                0.0
# Total expenditure                     7.69                 4.56
# Diphtheria                            0.647                0.0
# HIV/AIDS                              0.0                  0.0
# GDP                                   15.2                 7.96
# Population                            22.2                 14.7
# thinness  1-19 years                  1.16                 0.0
# thinness 5-9 years                    1.16                 0.0
# Income composition of resources       5.68                 0.0
# Schooling                             5.55                 0.0

# %%
# using pandas interpolation function to fill missing values
fill_cols = life_df.columns[life_df.isnull().sum() > 0]
countries = life_df['Country'].unique()

# save empty enteries stats
before_inter = (life_df.isnull().sum()/life_df.shape[0]*100).values

for country in countries:
    life_df.loc[life_df['Country'] == country, fill_cols] = life_df.loc[life_df['Country'] == country, fill_cols].interpolate(method='linear', limit_direction='both')

# print percent of empty cells before and after imputation
after_inter = (life_df.isnull().sum()/life_df.shape[0]*100).values
inter_ind = (life_df.isnull().sum()/life_df.shape[0]*100).index
print('{0:<32}      {1:<12}      {2:<12}'.format('', 'before', 'after')) 
for row in zip(inter_ind, before_inter, after_inter):
    print('{0:<32}      {1:<15.3}      {2:<15.3}'.format(*row))
# Out:
#                                       before            after
# Country                               0.0                  0.0
# Year                                  0.0                  0.0
# Status                                0.0                  0.0
# Life expectancy                       0.0                  0.0
# Adult Mortality                       0.0                  0.0
# infant deaths                         0.0                  0.0
# Alcohol                               4.8                  0.0
# percentage expenditure                0.0                  0.0
# Hepatitis B                           16.9                 4.54
# Measles                               0.0                  0.0
# BMI                                   0.0                  0.0
# under-five deaths                     0.0                  0.0
# Polio                                 0.0                  0.0
# Total expenditure                     5.03                 0.0
# Diphtheria                            0.0                  0.0
# HIV/AIDS                              0.0                  0.0
# GDP                                   8.78                 8.1
# Population                            16.2                 16.1
# thinness  1-19 years                  0.0                  0.0
# thinness 5-9 years                    0.0                  0.0
# Income composition of resources       0.0                  0.0
# Schooling                             0.0                  0.0

# %%
# Are there still rows with multiple missing entries?
na_count = life_df.isnull().sum(axis=1)
plt.hist(na_count)
plt.xlabel("Num of NA's/ row")
plt.xticks(np.arange(0, 3, 1))
plt.show()

# %%
# Use linear regression to fill missing values

# save empty enteries stats
nrow_before = life_df.shape[0]
before_impute = (life_df.isnull().sum()/nrow_before*100).values

# for each target column with missing values, select columns with more than 0.5 absloute correlation
target_cols = life_df.columns[(life_df.isnull().sum()/life_df.shape[0]*100) > 0]

# intitalize LinearRegression function
linreg = LinearRegression()

# generate correlation matrix
corr = life_df.corr()

for target_col in target_cols:
    cols_of_interest = corr.index[abs(corr[target_col]) > 0.5]

    # use linear regression to impute missing data in columns of interest
    data = life_df[cols_of_interest].copy()
    # drop rows with na's beside na rows in target col. Then, drop any columns with remaining na's
    for index, row in data.iterrows():
        if np.isnan(row[target_col]):
            data.drop(index=index, axis=1, inplace=True)
        elif np.isnan(row).sum() > 0:
            data.drop(index, inplace=True)
            
    
    # subset data to proper format for testing and training
    x_train = data[ data[target_col].notnull()].drop(columns=target_col)
    y_train = data[ data[target_col].notnull()][target_col]
    x_test = data[ data[target_col].isnull()].drop(columns=target_col)
    
    # train
    linreg.fit(x_train, y_train)
    
    #predict
    try:
        pred = linreg.predict(x_test)
        # fill missing values based on prediction
        life_df[target_col][life_df[target_col].isnull()] = pred
    except:
        print('Insufficient data for prediction. Rows with missing data will be eliminated')
        life_df = life_df[life_df.index.isin(data.index.tolist())]

# print percent of empty entries before and after imputation
nrow_after = life_df.shape[0]
after_impute = (life_df.isnull().sum()/nrow_after*100).values
impute_ind = (life_df.isnull().sum()/nrow_after*100).index
print('{0:<32}      {1:<12}{2}      {3:<12}{4}'.format('', 'before', nrow_before, 'after', nrow_after)) 
for row in zip(impute_ind, before_impute, after_impute):
    print('{0:<32}      {1:<15.3}      {2:<15.3}'.format(*row))
# Out:
# Insufficient data for prediction. Rows with missing data will be eliminated
# Insufficient data for prediction. Rows with missing data will be eliminated
# Insufficient data for prediction. Rows with missing data will be eliminated
#                                       before      2666      after       2117
# Country                               0.0                  0.0
# Year                                  0.0                  0.0
# Status                                0.0                  0.0
# Life expectancy                       0.0                  0.0
# Adult Mortality                       0.0                  0.0
# infant deaths                         0.0                  0.0
# Alcohol                               0.0                  0.0
# percentage expenditure                0.0                  0.0
# Hepatitis B                           4.54                 0.0
# Measles                               0.0                  0.0
# BMI                                   0.0                  0.0
# under-five deaths                     0.0                  0.0
# Polio                                 0.0                  0.0
# Total expenditure                     0.0                  0.0
# Diphtheria                            0.0                  0.0
# HIV/AIDS                              0.0                  0.0
# GDP                                   8.1                  0.0
# Population                            16.1                 0.0
# thinness  1-19 years                  0.0                  0.0
# thinness 5-9 years                    0.0                  0.0
# Income composition of resources       0.0                  0.0
# Schooling                             0.0                  0.0

# %%
life_df.describe(include='all')
# Out:
#             Country         Year      Status  Life expectancy  \
# count          2117  2117.000000        2117      2117.000000
# unique          133          NaN           2              NaN
# top     Afghanistan          NaN  Developing              NaN
# freq             16          NaN        1813              NaN
# mean            NaN  2007.510156         NaN        68.139254
# std             NaN     4.600538         NaN         9.626245
# min             NaN  2000.000000         NaN        36.300000
# 25%             NaN  2004.000000         NaN        62.000000
# 50%             NaN  2008.000000         NaN        69.900000
# 75%             NaN  2011.000000         NaN        74.800000
# max             NaN  2015.000000         NaN        89.000000
#
#         Adult Mortality  infant deaths      Alcohol  percentage expenditure  \
# count       2117.000000    2117.000000  2117.000000             2117.000000
# unique              NaN            NaN          NaN                     NaN
# top                 NaN            NaN          NaN                     NaN
# freq                NaN            NaN          NaN                     NaN
# mean         174.173831      36.076523     4.369051              642.698821
# std          129.989101     136.556755     3.997932             1714.794301
# min            1.000000       0.000000     0.010000                0.000000
# 25%           75.000000       1.000000     0.610000               20.218228
# 50%          152.000000       4.000000     3.630000               84.634389
# 75%          241.000000      24.000000     7.130000              431.485487
# max          723.000000    1800.000000    17.870000            18961.348600
#
#         Hepatitis B        Measles  ...        Polio  Total expenditure  \
# count   2117.000000    2117.000000  ...  2117.000000        2117.000000
# unique          NaN            NaN  ...          NaN                NaN
# top             NaN            NaN  ...          NaN                NaN
# freq            NaN            NaN  ...          NaN                NaN
# mean      74.460085    2671.142655  ...    80.609825           5.898111
# std       28.647224   11941.642546  ...    24.167849           2.305415
# min        2.000000       0.000000  ...     3.000000           0.370000
# 25%       64.000000       0.000000  ...    75.000000           4.360000
# 50%       87.000000      21.000000  ...    91.000000           5.790000
# 75%       95.000000     469.000000  ...    96.000000           7.380000
# max       99.000000  212183.000000  ...    99.000000          14.390000
#
#          Diphtheria     HIV/AIDS            GDP    Population  \
# count   2117.000000  2117.000000    2117.000000  2.117000e+03
# unique          NaN          NaN            NaN           NaN
# top             NaN          NaN            NaN           NaN
# freq            NaN          NaN            NaN           NaN
# mean      80.720359     2.184034    5424.655707  1.345302e+07
# std       24.212907     5.840598   11401.233398  6.331574e+07
# min        2.000000     0.100000       1.681350  3.400000e+01
# 25%       76.000000     0.100000     394.467675  1.999930e+05
# 50%       91.000000     0.100000    1355.745860  1.431776e+06
# 75%       96.000000     1.300000    4516.246750  7.815949e+06
# max       99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years  thinness 5-9 years  \
# count            2117.000000         2117.000000
# unique                   NaN                 NaN
# top                      NaN                 NaN
# freq                     NaN                 NaN
# mean                5.108503            5.178507
# std                 4.715725            4.809639
# min                 0.100000            0.100000
# 25%                 1.600000            1.600000
# 50%                 3.400000            3.400000
# 75%                 7.500000            7.600000
# max                27.700000           28.600000
#
#         Income composition of resources    Schooling
# count                       2117.000000  2117.000000
# unique                              NaN          NaN
# top                                 NaN          NaN
# freq                                NaN          NaN
# mean                           0.609011    11.724610
# std                            0.201656     3.156191
# min                            0.000000     0.000000
# 25%                            0.477000     9.800000
# 50%                            0.651000    11.900000
# 75%                            0.747000    13.800000
# max                            0.937000    20.700000
#
# [11 rows x 22 columns]

# %% [markdown]
# ## 2. Handling outliers and transforming data

# %%
# drop outliers beyond 3 std's
adj_life_df = life_df.copy()
num_cols = adj_life_df.columns[4:] # subset of numerical columns


adj_life_df = adj_life_df[(np.abs(zscore(adj_life_df.iloc[:,4:])) < 3).all(axis=1)]
adj_life_df.iloc[:, 4:] = np.sqrt(adj_life_df.iloc[:, 4:])

# boxplot vaisualization of data before and after winsorization
plt.figure(figsize=(20, 40))

for i in range(1, len(num_cols)+1):
    
    # original data boxplots
    ind = 3*((i-1)//3)+i # for 1st row, 3rd row...
    plt.subplot(12, 3, ind)
    sns.distplot(life_df[num_cols[i-1]])
    plt.title('{}'.format(num_cols[i-1]), fontsize=16)
    
    # outliers beyond 4-z dropped
    ind2 = 3*((i-1)//3+1)+i # for 2nd row, 4th row...
    plt.subplot(12, 3, ind2)
    sns.distplot(adj_life_df[num_cols[i-1]], color='r')
    plt.title('Square root transformed {}'.format(num_cols[i-1]), fontsize=16)

plt.tight_layout()
plt.show()

# %%
# normality test some data

cols = ['Adult Mortality', 'Alcohol', 'Population', 'thinness  1-19 years', 'thinness 5-9 years']

# Test distribution normality for these columns
for col in cols:
    print("------------------------------------------------")
    print("Comparisons for variable: {}".format(col))
    print("------------------------------------------------")

    jb_stats = jarque_bera(adj_life_df[col])
    norm_stats = normaltest(adj_life_df[col])
    print("Jarque-Bera test statistics on original data is {0:.3} and p value is {1:.3}".format(*jb_stats))
    print("Normality test statistics on original data is {0:.3} and p value is {1:.3}".format(*norm_stats))
    
    boxcox_jb_stats = jarque_bera(np.sqrt(adj_life_df[col]))
    boxcox_norm_stats  = normaltest(np.sqrt(adj_life_df[col]))
    print("Jarque-Bera test statistics on log transformed data is {0:.3} and p value is {1:.3}".format(*boxcox_jb_stats))
    print("Normality test statistics on log transformed data is {0:.3} and p value is {1:.3}".format(*boxcox_norm_stats))
# Out:
# ------------------------------------------------
# Comparisons for variable: Adult Mortality
# ------------------------------------------------
# Jarque-Bera test statistics on original data is 23.3 and p value is 8.72e-06
# Normality test statistics on original data is 33.7 and p value is 4.77e-08
# Jarque-Bera test statistics on log transformed data is 1.44e+02 and p value is 0.0
# Normality test statistics on log transformed data is 1.19e+02 and p value is 1.38e-26
# ------------------------------------------------
# Comparisons for variable: Alcohol
# ------------------------------------------------
# Jarque-Bera test statistics on original data is 99.6 and p value is 0.0
# Normality test statistics on original data is 1.07e+03 and p value is 1.36e-233
# Jarque-Bera test statistics on log transformed data is 1.58e+02 and p value is 0.0
# Normality test statistics on log transformed data is 2.14e+02 and p value is 3.42e-47
# ------------------------------------------------
# Comparisons for variable: Population
# ------------------------------------------------
# Jarque-Bera test statistics on original data is 3.5e+03 and p value is 0.0
# Normality test statistics on original data is 7.54e+02 and p value is 2.18e-164
# Jarque-Bera test statistics on log transformed data is 2.17e+02 and p value is 0.0
# Normality test statistics on log transformed data is 1.67e+02 and p value is 4.37e-37
# ------------------------------------------------
# Comparisons for variable: thinness  1-19 years
# ------------------------------------------------
# Jarque-Bera test statistics on original data is 81.9 and p value is 0.0
# Normality test statistics on original data is 90.6 and p value is 2.1e-20
# Jarque-Bera test statistics on log transformed data is 26.6 and p value is 1.66e-06
# Normality test statistics on log transformed data is 57.3 and p value is 3.56e-13
# ------------------------------------------------
# Comparisons for variable: thinness 5-9 years
# ------------------------------------------------
# Jarque-Bera test statistics on original data is 71.9 and p value is 2.22e-16
# Normality test statistics on original data is 79.3 and p value is 6.03e-18
# Jarque-Bera test statistics on log transformed data is 22.5 and p value is 1.3e-05
# Normality test statistics on log transformed data is 43.5 and p value is 3.55e-10

# %% [markdown]
# Distribution is not normal for most data but it's the closest it got after trying log and quantile trnasformations

# %%
# check correlation matrix after transformation
corr = adj_life_df.corr()
corr.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
#     #T_3278723e_acc6_11e9_9055_109add48ac16row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col1 {
#             background-color:  #edf2f5;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col2 {
#             background-color:  #b8d8e9;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col3 {
#             background-color:  #acd2e5;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col4 {
#             background-color:  #337eb8;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col5 {
#             background-color:  #6eaed2;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col6 {
#             background-color:  #b6d7e8;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col7 {
#             background-color:  #1c5c9f;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col8 {
#             background-color:  #bbdaea;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col9 {
#             background-color:  #b6d7e8;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col10 {
#             background-color:  #7eb8d7;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col11 {
#             background-color:  #75b2d4;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col12 {
#             background-color:  #8dc2dc;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col13 {
#             background-color:  #cfe4ef;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col14 {
#             background-color:  #b8d8e9;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col15 {
#             background-color:  #175290;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col16 {
#             background-color:  #cae1ee;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col17 {
#             background-color:  #c5dfec;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col18 {
#             background-color:  #e0ecf3;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row0_col19 {
#             background-color:  #e6eff4;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col0 {
#             background-color:  #68abd0;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col2 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col3 {
#             background-color:  #0a3b70;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col4 {
#             background-color:  #fcdecd;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col5 {
#             background-color:  #fac8af;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col6 {
#             background-color:  #a2cde3;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col7 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col8 {
#             background-color:  #f5a886;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col9 {
#             background-color:  #0a3b70;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col10 {
#             background-color:  #f7f5f4;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col11 {
#             background-color:  #cae1ee;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col12 {
#             background-color:  #f7f5f4;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col13 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col14 {
#             background-color:  #f7b799;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col15 {
#             background-color:  #15508d;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col16 {
#             background-color:  #08366a;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col17 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col18 {
#             background-color:  #991027;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row1_col19 {
#             background-color:  #bf3338;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col0 {
#             background-color:  #4291c2;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col1 {
#             background-color:  #276eb0;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col3 {
#             background-color:  #fae8de;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col4 {
#             background-color:  #3c8abe;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col5 {
#             background-color:  #1d5fa2;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col6 {
#             background-color:  #2065ab;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col7 {
#             background-color:  #87beda;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col8 {
#             background-color:  #337eb8;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col9 {
#             background-color:  #fbe3d4;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col10 {
#             background-color:  #2065ab;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col11 {
#             background-color:  #2369ad;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col12 {
#             background-color:  #1d5fa2;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col13 {
#             background-color:  #f6b191;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col14 {
#             background-color:  #1c5c9f;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col15 {
#             background-color:  #1a5899;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col16 {
#             background-color:  #fce0d0;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col17 {
#             background-color:  #fce0d0;
#             color:  #000000;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col18 {
#             background-color:  #2267ac;
#             color:  #f1f1f1;
#         }    #T_3278723e_acc6_11e9_9055_109add48ac16row2_col19 {
#             background-color:  #2267ac;

# %% [markdown]
# ***
# ## 3. Dimensionality reduction

# %%
adj_life_df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 1  Afghanistan  2014  Developing             59.9        16.462078
# 2  Afghanistan  2013  Developing             59.9        16.370706
# 3  Afghanistan  2012  Developing             59.5        16.492423
# 4  Afghanistan  2011  Developing             59.2        16.583124
# 5  Afghanistan  2010  Developing             58.8        16.703293
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B    Measles  \
# 1       8.000000      0.1                8.574589     7.874008  22.181073
# 2       8.124038      0.1                8.556824     8.000000  20.736441
# 3       8.306624      0.1                8.842184     8.185353  52.792045
# 4       8.426150      0.1                2.664040     8.246211  54.890801
# 5       8.602325      0.1                8.926330     8.124038  44.598206
#
#    ...     Polio  Total expenditure  Diphtheria  HIV/AIDS        GDP  \
# 1  ...  7.615773           2.860070    7.874008  0.316228  24.752707
# 2  ...  7.874008           2.851315    8.000000  0.316228  25.134538
# 3  ...  8.185353           2.918904    8.185353  0.316228  25.883566
# 4  ...  8.246211           2.805352    8.246211  0.316228   7.971024
# 5  ...  8.124038           3.033150    8.124038  0.316228  23.522945
#
#     Population  thinness  1-19 years  thinness 5-9 years  \
# 1   572.347796              4.183300            4.183300
# 2  5633.088673              4.207137            4.207137
# 3  1922.747513              4.230839            4.242641
# 4  1725.861814              4.266146            4.266146
# 5  1697.989105              4.289522            4.289522
#
#    Income composition of resources  Schooling
# 1                         0.689928   3.162278
# 2                         0.685565   3.146427
# 3                         0.680441   3.130495
# 4                         0.673795   3.082207
# 5                         0.669328   3.033150
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 3.1. PCA

# %%
longivity_cutoff = adj_life_df['Life expectancy'].mean() + 1.5*adj_life_df['Life expectancy'].std()
p_cutoff = (adj_life_df['Life expectancy'] < longivity_cutoff).sum()/len(adj_life_df['Life expectancy'])
print(longivity_cutoff)
print(p_cutoff)
ax = sns.distplot(adj_life_df['Life expectancy'])
# fill area under distribution curve
line = ax.lines[0]
x1 = line.get_xydata()[:,0]
y1 = line.get_xydata()[:,1]
ax.fill_between(x1[x1<longivity_cutoff],y1[x1<longivity_cutoff], color="blue", alpha=0.9)
ax.text(s='{:.3}%'.format(p_cutoff*100), x=70, y=0.02, fontdict={'size':12, 'color':'white'})
plt.show()
# Out:
# 82.1955312578472
# 0.9716312056737588

# %%
# make target column categorial
pca_life_df = adj_life_df.copy()
pca_life_df['Longevity'] = np.where(pca_life_df['Life expectancy'] > longivity_cutoff, 'Long lived', 'Not long lived')
pca_life_df.drop('Life expectancy', axis=1, inplace=True)

# split dataset
data = pca_life_df.loc[:, ~pca_life_df.columns.isin(['Longevity', 'Country', 'Status'])]
data_cols = data.columns
target = pca_life_df.loc[:, pca_life_df.columns == 'Longevity']
target.reset_index(inplace=True, drop=True)

# feature scaling
data = StandardScaler().fit_transform(data)

# initialize and fit PCA
pca = PCA(n_components=2)
pca_data = pca.fit_transform(data)

# explained variance
explained_var = pca.explained_variance_ratio_
print('Principal component 1 explains {:.0f}% and component 2 expalins {:.0f}%'.format(*explained_var*100))

# visualize 2D-PCA
plt.figure()
colors = ['navy', 'darkorange']
target_names = ['Long lived', 'Not long lived']
for color, i, target_name in zip(colors, [0, 1], target_names):
    plt.scatter(pca_data[np.where(target == target_name)[0], 0], pca_data[np.where(target == target_name)[0], 1], color=color, 
                alpha=.5, lw=12, label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA of Countries Life Span')
plt.show()
# Out:
# Principal component 1 explains 35% and component 2 expalins 10%

# %%
# features contribution to principal components
plt.figure(figsize=(20, 5))
df = pd.DataFrame(pca.components_,columns=data_cols,index = ['PC-1','PC-2'])
sns.heatmap(df, annot=True, cmap='RdBu_r')
plt.show()

# %% [markdown]
# Population has little contribution to both principal components. The data set has many missing population entriesand this led to many entries (rows) being eliminated in this analysis. Section __1. Handling missing data__, will be improved below (__4. Improved handling missing data__) to exclude this feature.
#
# GDP feature has also 15% of it's initial entries missing and has small contribution to PC's. Could also be eliminated from analysis

# %% [markdown]
# ## 3.2. LDA

# %%
# make target column categorial
lda_life_df = adj_life_df.copy()
lda_life_df['Longivity'] = np.where(lda_life_df['Life expectancy'] > longivity_cutoff, 'Long lived', 'Not long lived')
lda_life_df.drop('Life expectancy', axis=1, inplace=True)

# split dataset into test and train
data = lda_life_df.loc[:, ~lda_life_df.columns.isin(['Longivity', 'Country', 'Status'])]
target = lda_life_df.loc[:, lda_life_df.columns == 'Longivity']
target.reset_index(inplace=True, drop=True)

# initialize and fit LDA 
lda = LinearDiscriminantAnalysis(n_components = 2)
lda_data = lda.fit_transform(data, target)
print(lda.explained_variance_ratio_)

# visualizing 1D-LDA
target['LDA-1'] = lda_data
sns.stripplot(y='LDA-1', x='Longivity', data=target)
plt.show()
# Out:
# /Users/wesamazaizeh/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/wesamazaizeh/miniconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:466: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(19, 2 - 1) = 1 components.
#   ChangedBehaviorWarning)
# /Users/wesamazaizeh/miniconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# [1.]
# /Users/wesamazaizeh/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# In the case when the number of different class labels, C, is less than the number of observations (almost always), then linear discriminant analysis will always produce C - 1 discriminating components. Because the number of different classes is 2, the dimensionality of the linear discriminant model can be at most 1-dimensional.

# %% [markdown]
# ## 4. Improved handling missing data

# %%
life_df2 = life_df_copy.copy()
life_df2.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0               8.18        62.0       0.1  612.696514    327582.0
# 2   62.0               8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0               8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0               7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                  17.2                17.3                            0.479
# 1                  17.5                17.5                            0.476
# 2                  17.7                17.7                            0.470
# 3                  17.9                18.0                            0.463
# 4                  18.2                18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
life_df2.isnull().sum()/life_df2.shape[0]*100
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
# BMI                                 1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
# HIV/AIDS                            0.000000
# GDP                                15.248468
# Population                         22.191967
# thinness  1-19 years                1.157250
# thinness 5-9 years                  1.157250
# Income composition of resources     5.684139
# Schooling                           5.547992
# dtype: float64

# %%
# using pandas interpolation function to fill missing values
fill_cols = life_df2.columns[life_df2.isnull().sum() > 0]
countries = life_df2['Country'].unique()

# save empty enteries stats
before_inter = (life_df2.isnull().sum()/life_df2.shape[0]*100).values

for country in countries:
    life_df2.loc[life_df2['Country'] == country, fill_cols] = life_df2.loc[life_df2['Country'] == country, fill_cols].interpolate(method='linear', limit_direction='both')

# print percent of empty cells before and after imputation
after_inter = (life_df2.isnull().sum()/life_df2.shape[0]*100).values
inter_ind = (life_df2.isnull().sum()/life_df2.shape[0]*100).index
print('{0:<32}      {1:<12}      {2:<12}'.format('', 'before', 'after')) 
for row in zip(inter_ind, before_inter, after_inter):
    print('{0:<32}      {1:<15.3}      {2:<15.3}'.format(*row))
# Out:
#                                       before            after
# Country                               0.0                  0.0
# Year                                  0.0                  0.0
# Status                                0.0                  0.0
# Life expectancy                       0.34                 0.34
# Adult Mortality                       0.34                 0.34
# infant deaths                         0.0                  0.0
# Alcohol                               6.6                  0.579
# percentage expenditure                0.0                  0.0
# Hepatitis B                           18.8                 4.9
# Measles                               0.0                  0.0
# BMI                                   1.16                 1.16
# under-five deaths                     0.0                  0.0
# Polio                                 0.647                0.0
# Total expenditure                     7.69                 1.09
# Diphtheria                            0.647                0.0
# HIV/AIDS                              0.0                  0.0
# GDP                                   15.2                 13.8
# Population                            22.2                 22.1
# thinness  1-19 years                  1.16                 1.16
# thinness 5-9 years                    1.16                 1.16
# Income composition of resources       5.68                 5.68
# Schooling                             5.55                 5.55

# %%
# Eliminate features with significant percentage of missing data
life_df2.drop(['Population', 'GDP'], axis=1, inplace=True)

# distribution of num of missing values per row?
na_count = life_df2.isnull().sum(axis=1)
plt.hist(na_count)
plt.xlabel("Num of NA's/ row")
plt.show()
to_drop_count = (life_df2.isnull().sum(axis=1) > 0).sum()
print('{} ({:.0f}%) row have missing values'.format(to_drop_count, to_drop_count/life_df2.shape[0]*100))
# Out:
# 330 (11%) row have missing values

# %%
## drop rows with missing values

# save empty enteries stats
nrow_before = life_df2.shape[0]
before_impute = (life_df2.isnull().sum()/nrow_before*100).values

# drop 
life_df2 = life_df2[na_count == 0]

# print percent of empty entries before and after imputation
nrow_after = life_df2.shape[0]
after_impute = (life_df2.isnull().sum()/nrow_after*100).values
impute_ind = (life_df2.isnull().sum()/nrow_after*100).index
print('{0:<32}      {1:<12}{2}      {3:<12}{4}'.format('', 'before', nrow_before, 'after', nrow_after)) 
for row in zip(impute_ind, before_impute, after_impute):
    print('{0:<32}      {1:<15.3}      {2:<15.3}'.format(*row))
# Out:
#                                       before      2938      after       2608
# Country                               0.0                  0.0
# Year                                  0.0                  0.0
# Status                                0.0                  0.0
# Life expectancy                       0.34                 0.0
# Adult Mortality                       0.34                 0.0
# infant deaths                         0.0                  0.0
# Alcohol                               0.579                0.0
# percentage expenditure                0.0                  0.0
# Hepatitis B                           4.9                  0.0
# Measles                               0.0                  0.0
# BMI                                   1.16                 0.0
# under-five deaths                     0.0                  0.0
# Polio                                 0.0                  0.0
# Total expenditure                     1.09                 0.0
# Diphtheria                            0.0                  0.0
# HIV/AIDS                              0.0                  0.0
# thinness  1-19 years                  1.16                 0.0
# thinness 5-9 years                    1.16                 0.0
# Income composition of resources       5.68                 0.0
# Schooling                             5.55                 0.0

# %% [markdown]
# ## 5. Improved outlier elimination and data transformation

# %%
# # drop outliers beyond 3 std's
# adj_life_df2 = life_df2.copy()
# adj_life_df2 = adj_life_df2[(np.abs(zscore(adj_life_df2.iloc[:,4:])) < 3).all(axis=1)]
# num_cols2 = adj_life_df2.columns[4:] # subset of numerical columns

# # boxcox transform
# boxcox_df2 = pd.DataFrame(columns=num_cols2)
# lambda_output = np.zeros(boxcox_df2.shape[1])
# for i, col in zip(range(1,len(num_cols2)+1), num_cols2):
#     boxcox_df2[col], lambda_output[i-1] = boxcox(adj_life_df2[col]+1)
    
# # boxplot vaisualization of data before and after transformation
# plt.figure(figsize=(20, 40))

# for i, col in zip(range(1, len(num_cols2)+1), num_cols2):
#     # original data boxplots
#     ind = 3*((i-1)//3)+i # for 1st row, 3rd row...
#     plt.subplot(12, 3, ind)
#     sns.distplot(life_df2[col])
#     plt.title('{}'.format(col), fontsize=16)
#     plt.xlabel('')
    
#     # transformed data boxplots
#     ind2 = 3*((i-1)//3+1)+i # for 2nd row, 4th row...
#     plt.subplot(12, 3, ind2)
#     sns.distplot(boxcox_df2[col], color='r')
#     plt.title('Boxcox transformed {}'.format(col), fontsize=16)
#     plt.xlabel('')

# plt.tight_layout()
# plt.show()

# %%
# drop outlires
adj_life_df2 = life_df2.iloc[(np.abs(zscore(life_df2.iloc[:,3:])) < 3).all(axis=1), 3:]

# Try to decrease skewness via akew_autotransform
adj_life_df2 = skew_autotransform.skew_autotransform(adj_life_df2.copy(deep=True), plot = True, threshold = 0.5)

print('Original average skewness value was %2.2f' %(np.mean(abs(life_df2.iloc[:,4:].skew()))))
print('Average skewness after transformation is %2.2f' %(np.mean(abs(adj_life_df2.skew()))))
# Out:
#  ------------------------------------------------------
#
#  'Life expectancy' had 'negative' skewness of -0.77
#
#  Transformation yielded skewness of -0.07
#  ------------------------------------------------------
#
#  'Adult Mortality' had 'positive' skewness of 0.76
#
#  Transformation yielded skewness of -0.14
#  ------------------------------------------------------
#
#  'infant deaths' had 'positive' skewness of 4.89
#
#  Transformation yielded skewness of -0.16
#  ------------------------------------------------------
#
#  'Alcohol' had 'positive' skewness of 0.69
#
#  Transformation yielded skewness of -0.37
#  ------------------------------------------------------
#
#  'percentage expenditure' had 'positive' skewness of 3.22
#
#  Transformation yielded skewness of -0.22
#  ------------------------------------------------------
#
#  'Hepatitis B' had 'negative' skewness of -1.88
#
#  Transformation yielded skewness of -1.04
#  ------------------------------------------------------
#
#  'Measles' had 'positive' skewness of 5.36
#
#  Transformation yielded skewness of -0.01
#  ------------------------------------------------------
#
#  NO TRANSFORMATION APPLIED FOR 'BMI' . Skewness = -0.37
#  ------------------------------------------------------
#
#  'under-five deaths' had 'positive' skewness of 4.58
#
#  Transformation yielded skewness of -0.15
#  ------------------------------------------------------
#
#  'Polio' had 'negative' skewness of -1.87
#
#  Transformation yielded skewness of -0.63
#  ------------------------------------------------------
#
#  NO TRANSFORMATION APPLIED FOR 'Total expenditure' . Skewness = 0.26
#  ------------------------------------------------------
#
#  'Diphtheria' had 'negative' skewness of -2.05
#
#  Transformation yielded skewness of -0.65
#  ------------------------------------------------------
#
#  'HIV/AIDS' had 'positive' skewness of 3.64
#
#  Transformation yielded skewness of 0.71
#  ------------------------------------------------------
#
#  'thinness  1-19 years' had 'positive' skewness of 1.18
#
#  Transformation yielded skewness of -0.04
#  ------------------------------------------------------
#
#  'thinness 5-9 years' had 'positive' skewness of 1.22
#
#  Transformation yielded skewness of -0.05
#  ------------------------------------------------------
#
#  'Income composition of resources' had 'negative' skewness of -0.56
#
#  Transformation yielded skewness of -0.17
#  ------------------------------------------------------
#
#  NO TRANSFORMATION APPLIED FOR 'Schooling' . Skewness = -0.47
# Original average skewness value was 3.24
# Average skewness after transformation is 0.32

# %% [markdown]
# # 6. Dimensionality reduction
# ## 6.1. PCA

# %%
# preparing data
longivity_cutoff = adj_life_df2['Life expectancy'].mean() + 1.5*life_df2['Life expectancy'].std()
p_cutoff = (life_df2['Life expectancy'] < longivity_cutoff).sum()/len(life_df2['Life expectancy'])
print('Longivity cutoff is {:.1f} years'.format(longivity_cutoff))

ax = sns.distplot(life_df2['Life expectancy'])
# fill area under distribution curve
line = ax.lines[0]
x1 = line.get_xydata()[:,0]
y1 = line.get_xydata()[:,1]
ax.fill_between(x1[x1<longivity_cutoff],y1[x1<longivity_cutoff], color="blue", alpha=0.9)
ax.text(s='{:.3}%'.format(p_cutoff*100), x=70, y=0.02, fontdict={'size':12, 'color':'white'})
plt.show()

# make target column categorial
pca_life_df2 = adj_life_df2.copy()
pca_life_df2['Longevity'] = np.where(adj_life_df2['Life expectancy'] > longivity_cutoff, 'Long lived', 'Not long lived')
pca_life_df2.drop('Life expectancy', axis=1, inplace=True)


# split dataset
data = pca_life_df2.loc[:, pca_life_df2.columns != 'Longevity']
data_cols = data.columns
target = pca_life_df2.loc[:, pca_life_df2.columns == 'Longevity']
target.reset_index(inplace=True, drop=True)

# feature scaling
data = StandardScaler().fit_transform(data)

# initialize and fit PCA
pca = PCA(n_components=2)
pca_data2 = pca.fit_transform(data)

# explained variance
explained_var = pca.explained_variance_ratio_
print('Principal component 1 explains {:.0f}% and component 2 expalins {:.0f}%'.format(*explained_var*100))

# visualize 2D-PCA
plt.figure()
colors = ['navy', 'darkorange']
target_names = ['Long lived', 'Not long lived']
for color, i, target_name in zip(colors, [0, 1], target_names):
    plt.scatter(pca_data2[np.where(target == target_name)[0], 0], pca_data2[np.where(target == target_name)[0], 1], color=color, 
                alpha=.5, lw=12, label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA of Countries Life Span')
plt.show()
# Out:
# Longivity cutoff is 554405.2 years
# Principal component 1 explains 41% and component 2 expalins 13%

# %% [markdown]
# ## 6.2. LDA

# %%
# make target column categorial
lda_life_df2 = adj_life_df2.copy()
lda_life_df2['Longivity'] = np.where(lda_life_df2['Life expectancy'] > longivity_cutoff, 'Long lived', 'Not long lived')
lda_life_df2.drop('Life expectancy', axis=1, inplace=True)

# split dataset into test and train
data = lda_life_df2.loc[:, ~lda_life_df2.columns.isin(['Longivity', 'Country', 'Status'])]
target = lda_life_df2.loc[:, lda_life_df2.columns == 'Longivity']
target.reset_index(inplace=True, drop=True)

# initialize and fit LDA 
lda = LinearDiscriminantAnalysis(n_components = 2)
lda_data = lda.fit_transform(data, target)

# visualizing 1D-LDA
target['LDA-1'] = lda_data
sns.stripplot(y='LDA-1', x='Longivity', data=target)
plt.show()
# Out:
# /Users/wesamazaizeh/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/wesamazaizeh/miniconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:466: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(16, 2 - 1) = 1 components.
#   ChangedBehaviorWarning)
# /Users/wesamazaizeh/miniconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# /Users/wesamazaizeh/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# Still does not acheive satisfactory separation

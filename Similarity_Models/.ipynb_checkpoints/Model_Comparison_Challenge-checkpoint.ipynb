# %% [markdown]
# ### Bike Sharing Data Set
# Data source: https://code.datasciencedojo.com/toobamukhtar/datasets/tree/5a283b2d7a66be24b8f709a4335729b96990d683/Bike%20Sharing
#
#
# ### Predict bike rental count (hourly/daily) based on the environmental & seasonal settings
#
# Bike-sharing rental process is highly correlated to the environmental and seasonal settings. For instance, weather conditions, precipitation, day of week, season, hour of the day, etc. can affect the rental behaviors.
#
# This dataset contains the hourly and daily count of rental bikes between years 2011 and 2012 for Capital
# bikeshare system with the corresponding weather and seasonal information.
#
# This dataset contains 2 files: Bike sharing counts aggregated on hourly basis (hour.csv - 17379 rows, 17 columns) & bike sharing counts aggregated on daily basis (day.csv - 731 rows, 16 columns)
# ___

# %% [markdown]
# ### Challenge:
# Build a KNN Regression and an OLS regression. Compare the two. How similar are they? Do they miss in different ways?
#
# Create a Jupyter notebook with your models. At the end in a markdown cell write a few paragraphs to describe the models' behaviors and why you favor one model or the other. Try to determine whether there is a situation where you would change your mind, or whether one is unambiguously better than the other. Lastly, try to note what it is about the data that causes the better model to outperform the weaker model. Submit a link to your notebook below.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.ticker as ticker
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %%
bike_filepath = '/Users/wesamazaizeh/Desktop/Thinkful_Main_Course/Similarity_Models/Bike Sharing/day.csv'
bike_df = pd.read_csv(bike_filepath)
bike_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ## Data preperation

# %%
# visualize % of nulls per column
plt.figure(figsize=(8,8))
sns.distplot(bike_df.isnull().sum()/bike_df.shape[0]*100, kde=False)
plt.xlabel('% of nulls per column', size=26)
plt.ylabel('%', size=26)
plt.show()

# %% [markdown]
# - No missing data

# %%
# distribution of target variable
plt.figure(figsize=(10,8))
sns.distplot(bike_df.cnt)
plt.xlabel('Daily bike count', size=26)
plt.show()

# %% [markdown]
# - The target variable seems normally distributed

# %% [markdown]
# ## Feature selection:
#
# ### 1. Using PCA to find features that contribute the most to variance within samples

# %%
bike_df.iloc[:,2:-3].shape
# Out:
# (731, 11)

# %%
# PCA of most informative features
data = bike_df.iloc[:,2:-3]

z_data = StandardScaler().fit_transform(data)
pca_res = PCA().fit(z_data)

plt.figure(figsize = (10,7))
sns.set_context( rc={'lines.markersize': 10, 'xtick.labelsize': 16, 'ytick.labelsize': 16}) # override marker and ticklabel size
g = sns.lineplot(y=pca_res.explained_variance_ratio_, x=list(range(1,12)), marker="o", label='Idvidual')
sns.lineplot(y=pca_res.explained_variance_ratio_.cumsum(), x=list(range(1,12)), marker="o", label='Cumulative')
sns.set_style('darkgrid')
plt.setp(g.lines,linewidth=3) # for line width
g.lines[1].set_linestyle("--") # for line style
plt.setp(g.get_legend().get_texts(), fontsize='16') # for legend text
plt.xlabel('Principal component', fontsize='16') # x-axis label
plt.ylabel('Explained variance ratio', fontsize='16') # y-axis label
g.set(xticks=list(range(1,12)))
plt.show()

print('PCA 1st component explains {:.3}% of the expenditure variance'.format(pca_res.explained_variance_ratio_[0]*100))
# Out:
# PCA 1st component explains 24.3% of the expenditure variance

# %%
# heatmap of variables vs principal components
fig, ax = plt.subplots(figsize=(10,7)) 
cols = list(bike_df.iloc[:,2:-1].columns)
sns.set_context(rc={'axes.labelsize':16})
sns.heatmap(np.log(pca_res.inverse_transform(np.eye(data.shape[1]))), cmap="hot")
ax.set_xticklabels(cols) # set x-ticks labels
plt.xticks(rotation=60) # rotate x-tixks so they fit next to each other
plt.ylabel('Principal components') # y-axis label
plt.show()

# mean and variance of variables contributing to 1st principal component
pca_inv_res = pca_res.inverse_transform(np.eye(data.shape[1]))
fig, ax = plt.subplots(figsize=(10,7)) 
plt.plot(pca_inv_res.mean(axis=0), '--o', label = 'mean')
plt.plot(np.square(pca_inv_res.std(axis=0)), '--o', label = 'variance')
plt.ylabel('feature contribution', fontsize=16);
ax.xaxis.set_major_locator(ticker.FixedLocator((list(range(13))))) # manually setting xticks position
ax.xaxis.set_major_formatter(ticker.FixedFormatter((cols))) # manually setting xticks labels
ax.set_xticklabels(cols, rotation=60, ha='right') # rotating and correcting xticks position
plt.legend(loc='lower left', fontsize=16)
plt.show()

# %% [markdown]
# PCA dimensionality reduction doesn't seem efficient enough for this model. In order to explain more than 90% of the variance in the outcome, we 9 or 9 PC are needed, which is not a great improvement from the 13 original features.
# ## 2. Using highest correlation to target value and low correlation with other features

# %%
corr = bike_df.drop(['casual', 'registered', 'instant'], axis=1).corr()
corr.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
#     #T_f227254a_f51d_11e9_9661_109add48ac16row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col1 {
#             background-color:  #2065ab;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col2 {
#             background-color:  #bf3338;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col3 {
#             background-color:  #408fc1;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col4 {
#             background-color:  #1d5fa2;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col5 {
#             background-color:  #4c99c6;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col6 {
#             background-color:  #65a9cf;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col7 {
#             background-color:  #dae9f2;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col8 {
#             background-color:  #e1edf3;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col9 {
#             background-color:  #bbdaea;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col10 {
#             background-color:  #08366a;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row0_col11 {
#             background-color:  #f9ebe3;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col0 {
#             background-color:  #3e8cbf;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col2 {
#             background-color:  #3885bc;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col3 {
#             background-color:  #4997c5;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col4 {
#             background-color:  #1d5fa2;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col5 {
#             background-color:  #4393c3;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col6 {
#             background-color:  #408fc1;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col7 {
#             background-color:  #3b88be;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col8 {
#             background-color:  #408fc1;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col9 {
#             background-color:  #246aae;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col10 {
#             background-color:  #3f8ec0;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row1_col11 {
#             background-color:  #f7b799;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col0 {
#             background-color:  #bf3338;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col1 {
#             background-color:  #2065ab;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col3 {
#             background-color:  #4f9bc7;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col4 {
#             background-color:  #2065ab;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col5 {
#             background-color:  #4291c2;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col6 {
#             background-color:  #75b2d4;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col7 {
#             background-color:  #a2cde3;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col8 {
#             background-color:  #aed3e6;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col9 {
#             background-color:  #c2ddec;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col10 {
#             background-color:  #0e4179;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row2_col11 {
#             background-color:  #e1edf3;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col0 {
#             background-color:  #3b88be;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col1 {
#             background-color:  #2369ad;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col2 {
#             background-color:  #3f8ec0;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col3 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col4 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col5 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col6 {
#             background-color:  #4393c3;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col7 {
#             background-color:  #246aae;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col8 {
#             background-color:  #2a71b2;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col9 {
#             background-color:  #3e8cbf;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col10 {
#             background-color:  #4695c4;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row3_col11 {
#             background-color:  #3b88be;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col0 {
#             background-color:  #3e8cbf;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col1 {
#             background-color:  #1f63a8;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col2 {
#             background-color:  #3c8abe;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col3 {
#             background-color:  #276eb0;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col4 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col5 {
#             background-color:  #5ca3cb;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col6 {
#             background-color:  #6bacd1;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col7 {
#             background-color:  #2c75b4;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col8 {
#             background-color:  #327cb7;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col9 {
#             background-color:  #3480b9;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col10 {
#             background-color:  #4997c5;
#             color:  #000000;
#         }    #T_f227254a_f51d_11e9_9661_109add48ac16row4_col11 {
#             background-color:  #81bad8;
#             color:  #0

# %%
# selecting features that are highly correlated (>0.5) with target
cor_keep = corr['cnt'][np.abs(corr['cnt']) > 0.5].sort_values(ascending=False)

# eliminate intercorrelated feature
corr2 = bike_df[cor_keep.index].corr()
corr2.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
#     #T_2b63b04c_f51e_11e9_98ef_109add48ac16row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row0_col1 {
#             background-color:  #fcd5bf;
#             color:  #000000;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row0_col2 {
#             background-color:  #fcd7c2;
#             color:  #000000;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row0_col3 {
#             background-color:  #faeae1;
#             color:  #000000;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row1_col0 {
#             background-color:  #327cb7;
#             color:  #000000;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row1_col2 {
#             background-color:  #6d0220;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row1_col3 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row2_col0 {
#             background-color:  #2e77b5;
#             color:  #000000;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row2_col1 {
#             background-color:  #6d0220;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row2_col3 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row3_col0 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row3_col1 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row3_col2 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_2b63b04c_f51e_11e9_98ef_109add48ac16row3_col3 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }</style><table id="T_2b63b04c_f51e_11e9_98ef_109add48ac16" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cnt</th>        <th class="col_heading level0 col1" >atemp</th>        <th class="col_heading level0 col2" >temp</th>        <th class="col_heading level0 col3" >yr</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b63b04c_f51e_11e9_98ef_109add48ac16level0_row0" class="row_heading level0 row0" >cnt</th>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row0_col1" class="data row0 col1" >0.631066</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row0_col2" class="data row0 col2" >0.627494</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row0_col3" class="data row0 col3" >0.56671</td>
#             </tr>
#             <tr>
#                         <th id="T_2b63b04c_f51e_11e9_98ef_109add48ac16level0_row1" class="row_heading level0 row1" >atemp</th>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row1_col0" class="data row1 col0" >0.631066</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row1_col2" class="data row1 col2" >0.991702</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row1_col3" class="data row1 col3" >0.0461061</td>
#             </tr>
#             <tr>
#                         <th id="T_2b63b04c_f51e_11e9_98ef_109add48ac16level0_row2" class="row_heading level0 row2" >temp</th>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row2_col0" class="data row2 col0" >0.627494</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row2_col1" class="data row2 col1" >0.991702</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row2_col3" class="data row2 col3" >0.0476036</td>
#             </tr>
#             <tr>
#                         <th id="T_2b63b04c_f51e_11e9_98ef_109add48ac16level0_row3" class="row_heading level0 row3" >yr</th>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row3_col0" class="data row3 col0" >0.56671</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row3_col1" class="data row3 col1" >0.0461061</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row3_col2" class="data row3 col2" >0.0476036</td>
#                         <td id="T_2b63b04c_f51e_11e9_98ef_109add48ac16row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %%
# drop temp since atemp is more highly correlated with count
cor_keep.drop('temp', inplace=True)

corr3 = bike_df[cor_keep.index].corr()
corr3.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
#     #T_4c38a518_f51e_11e9_9b49_109add48ac16row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_4c38a518_f51e_11e9_9b49_109add48ac16row0_col1 {
#             background-color:  #fcd5bf;
#             color:  #000000;
#         }    #T_4c38a518_f51e_11e9_9b49_109add48ac16row0_col2 {
#             background-color:  #faeae1;
#             color:  #000000;
#         }    #T_4c38a518_f51e_11e9_9b49_109add48ac16row1_col0 {
#             background-color:  #327cb7;
#             color:  #000000;
#         }    #T_4c38a518_f51e_11e9_9b49_109add48ac16row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_4c38a518_f51e_11e9_9b49_109add48ac16row1_col2 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_4c38a518_f51e_11e9_9b49_109add48ac16row2_col0 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_4c38a518_f51e_11e9_9b49_109add48ac16row2_col1 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_4c38a518_f51e_11e9_9b49_109add48ac16row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }</style><table id="T_4c38a518_f51e_11e9_9b49_109add48ac16" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >cnt</th>        <th class="col_heading level0 col1" >atemp</th>        <th class="col_heading level0 col2" >yr</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c38a518_f51e_11e9_9b49_109add48ac16level0_row0" class="row_heading level0 row0" >cnt</th>
#                         <td id="T_4c38a518_f51e_11e9_9b49_109add48ac16row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_4c38a518_f51e_11e9_9b49_109add48ac16row0_col1" class="data row0 col1" >0.631066</td>
#                         <td id="T_4c38a518_f51e_11e9_9b49_109add48ac16row0_col2" class="data row0 col2" >0.56671</td>
#             </tr>
#             <tr>
#                         <th id="T_4c38a518_f51e_11e9_9b49_109add48ac16level0_row1" class="row_heading level0 row1" >atemp</th>
#                         <td id="T_4c38a518_f51e_11e9_9b49_109add48ac16row1_col0" class="data row1 col0" >0.631066</td>
#                         <td id="T_4c38a518_f51e_11e9_9b49_109add48ac16row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_4c38a518_f51e_11e9_9b49_109add48ac16row1_col2" class="data row1 col2" >0.0461061</td>
#             </tr>
#             <tr>
#                         <th id="T_4c38a518_f51e_11e9_9b49_109add48ac16level0_row2" class="row_heading level0 row2" >yr</th>
#                         <td id="T_4c38a518_f51e_11e9_9b49_109add48ac16row2_col0" class="data row2 col0" >0.56671</td>
#                         <td id="T_4c38a518_f51e_11e9_9b49_109add48ac16row2_col1" class="data row2 col1" >0.0461061</td>
#                         <td id="T_4c38a518_f51e_11e9_9b49_109add48ac16row2_col2" class="data row2 col2" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## OLS regression

# %%
data = bike_df[cor_keep.drop('cnt').index]
target = bike_df.cnt

data_train, data_test, target_train, target_test = train_test_split(data, target, test_size = 0.2)

print("The number of observations in the training set is {}".format(data_train.shape[0]))
print("The number of observations in the test set is {}".format(data_test.shape[0]))

# data_train = sm.add_constant(data_train) # eliminated based on p_value of model fit

# fit an OLS model using statsmodels
results = sm.OLS(target_train, data_train).fit()

# print the summary results
print(results.summary())
# Out:
# The number of observations in the training set is 584
# The number of observations in the test set is 147
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.950
# Model:                            OLS   Adj. R-squared (uncentered):              0.950
# Method:                 Least Squares   F-statistic:                              5568.
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):                        0.00
# Time:                        21:28:40   Log-Likelihood:                         -4913.6
# No. Observations:                 584   AIC:                                      9831.
# Df Residuals:                     582   BIC:                                      9840.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       7203.3383    119.743     60.157      0.000    6968.158    7438.519
# yr          2128.6300     86.090     24.726      0.000    1959.544    2297.716
# ==============================================================================
# Omnibus:                       41.252   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.222
# Skew:                          -0.567   Prob(JB):                     6.19e-13
# Kurtosis:                       4.013   Cond. No.                         2.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - Constant P value > 0.05 (0.5). Therefore it was removed and that increased R-sqr from ~0.69 to ~0.95

# %%
features = cor_keep.drop('cnt').index
data = bike_df[features]
data['yr_atemp'] = data.yr * data.atemp
target = bike_df.cnt

data_train, data_test, target_train, target_test = train_test_split(data, target, test_size = 0.2)

print("The number of observations in the training set is {}".format(data_train.shape[0]))
print("The number of observations in the test set is {}".format(data_test.shape[0]))

# sm_data_train = sm.add_constant(data_train)

# fit an OLS model using statsmodels
results2 = sm.OLS(target_train, data_train).fit()

# print the summary results
print(results2.summary())
# Out:
# The number of observations in the training set is 584
# The number of observations in the test set is 147
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.955
# Method:                 Least Squares   F-statistic:                              4105.
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):                        0.00
# Time:                        21:32:09   Log-Likelihood:                         -4886.2
# No. Observations:                 584   AIC:                                      9778.
# Df Residuals:                     581   BIC:                                      9791.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       7201.0082    121.276     59.377      0.000    6962.815    7439.202
# yr          1536.0595    198.459      7.740      0.000    1146.274    1925.845
# yr_atemp    1210.6867    408.927      2.961      0.003     407.531    2013.842
# ==============================================================================
# Omnibus:                       17.804   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.123
# Skew:                          -0.361   Prob(JB):                     4.27e-05
# Kurtosis:                       3.554   Cond. No.                         9.06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - Adding the interaction term between year and apparent temp lead to only slight improvememnt in R-sqr, from ~0.950 to ~0.955

# %% [markdown]
# ## KNN regression model

# %%
# determine K
knn = neighbors.KNeighborsRegressor(n_neighbors=100)
knn_w = neighbors.KNeighborsRegressor(n_neighbors=100, weights='distance')

data = bike_df[cor_keep.drop('cnt').index]
target = bike_df.cnt
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size = 0.2)

rmse_val = []
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)
    model.fit(data_train, target_train)
    pred=model.predict(data_test)
    error = sqrt(mean_squared_error(target_test,pred))
    rmse_val.append(error)

curve = pd.DataFrame(rmse_val)
curve.plot()
plt.xlim((-1,20))
plt.xlabel('K vlaue', size=26)
plt.legend(['error'] )
plt.show()

# build model with K=4
knn = neighbors.KNeighborsRegressor(n_neighbors=4)
knn_w = neighbors.KNeighborsRegressor(n_neighbors=4, weights='distance')
data = bike_df[features]
target = bike_df.cnt
print('K value with biggest difference in slope: {}'.format(min_k))

knn.fit(data, target)

score = cross_val_score(knn, data, target, cv=10)
print("Unweighted Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
score_w = cross_val_score(knn_w, data, target, cv=20)
print("Weighted Accuracy: %0.2f (+/- %0.2f)" % (score_w.mean(), score_w.std() * 2))
# Out:
# K value with biggest difference in slope: 17
# Unweighted Accuracy: -0.64 (+/- 2.04)
# Weighted Accuracy: -0.89 (+/- 2.07)

# %% [markdown]
# Horrible models based on R-sqr values for the unweighted and weighted versions

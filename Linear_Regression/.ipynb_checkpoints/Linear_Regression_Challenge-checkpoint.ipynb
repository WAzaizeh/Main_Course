# %% [markdown]
# # The scenario
# The housing market is one of the most crucial parts of the economy for every country. Purchasing a home is one of the primary ways to build wealth and savings for people. In this respect, predicting prices in the housing market is a very central topic in economic and financial circles.
#
# The house price dataset from Kaggle includes several features of the houses along with their sale prices at the time they are sold. So far, in this module, you built and implemented some models using this dataset.
#
# In this challenge, you are required to improve your model with respect to its prediction performance.
#
# To complete this challenge, submit a Jupyter notebook containing your solutions to the following tasks.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from statsmodels.tools.eval_measures import mse, rmse

import warnings
warnings.filterwarnings('ignore')

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'houseprices'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))
house_price_df = pd.read_sql_query('select * from houseprices',con=engine)

# no need for an open connection, as we're only doing a single query
engine.dispose()


house_price_df.describe(include='all')
# Out:
#                  id   mssubclass mszoning  lotfrontage        lotarea street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %% [markdown]
# ## Data preperation

# %%
# visualize % of nulls per column
plt.figure(figsize=(8,8))
sns.distplot(house_price_df.isnull().sum()/house_price_df.shape[0]*100, kde=False)
plt.xlabel('% of nulls per column', size=26)
plt.ylabel('%', size=26)
plt.show()

# %%
# drop columns with more than 10% missing values
house_price_df2 = house_price_df.loc[:, house_price_df.isnull().sum()/house_price_df.shape[0] < 0.1]
print('{} columns dropped'.format(house_price_df.shape[1] - house_price_df2.shape[1]))
# Out:
# 6 columns dropped

# %%
# visualize num of nulls per row
plt.figure(figsize=(8,8))
sns.distplot(house_price_df2.isnull().sum(axis=1), kde=False)
plt.xlabel('Number of nulls per column', size=26)
plt.ylabel('Count', size=26)
plt.show()

# %%
# drop rows with missing values
n_row = house_price_df2.shape[0]
house_price_df2 = house_price_df2.loc[house_price_df2.isnull().sum(axis=1) == 0 ,:]
print('{} out of {} rows dropped'.format(n_row - house_price_df2.shape[0], n_row))
# Out:
# 122 out of 1460 rows dropped

# %% [markdown]
# ## Feature engineering
# 1. Create total property area feature

# %%
# Create total living area feature
house_price_df2['totalsf'] = house_price_df2.totalbsmtsf + house_price_df2.firstflrsf + house_price_df2.secondflrsf
house_price_df2.drop(['totalbsmtsf', 'firstflrsf', 'secondflrsf'], axis=1, inplace=True)

# %% [markdown]
# 2. Create mortgage APR feature

# %%
# Create mortgage APR feature
mortgage_file_path = '/Users/wesamazaizeh/Desktop/Thinkful_Main_Course/Linear_Regression/30-year-fixed-mortgage-rate-chart.csv'
mortgage_apr_df = pd.read_csv(mortgage_file_path, skiprows=15)

mortgage_apr_df['date'] = pd.to_datetime( mortgage_apr_df.date, format='%Y-%m-%d')
mortgage_apr_df['year'] = mortgage_apr_df.date.dt.year
mortgage_apr_df['month'] = mortgage_apr_df.date.dt.month

house_price_df2 = pd.merge(house_price_df2, mortgage_apr_df, left_on=['yrsold','mosold'], right_on=['year', 'month'], how='left').drop(['date', 'year', 'month'], axis=1)
house_price_df2.rename(columns={' value':'interest'}, inplace=True)

# %% [markdown]
# 3. Create unemployment and CPI features
#
#
# - Local unemployment in percent, not seasonally adjusted.
# - The Consumer Price Index (CPI) is a measure of the average change over time in the prices paid by urban consumers for a market basket of consumer goods and services.

# %%
# Create unemployment rate feature
unemp_file_path = '/Users/wesamazaizeh/Desktop/Thinkful_Main_Course/Linear_Regression/local_unemployment_rate_2006to2009.csv'
unemp_df = pd.read_csv(unemp_file_path)

unemp_df2 = pd.DataFrame(columns=['year', 'month', 'value'])
years = range(2006, 2011)
months = range(1, 13)
for y, year in enumerate(years):
    for m, month in enumerate(months):
        ind = y*12+m
        unemp_df2.loc[ind, 'year'] = year
        unemp_df2.loc[ind, 'month'] = month
        unemp_df2.loc[ind, 'value'] = unemp_df.iloc[np.where(unemp_df['Year'] == 2006)[0], month][0]

house_price_df2 = pd.merge(house_price_df2, unemp_df2, left_on=['yrsold','mosold'], right_on=['year', 'month'], how='left').drop([ 'year', 'month'], axis=1)
house_price_df2.rename(columns={'value':'unemprate'}, inplace=True)

# Create consumer price index (CPI) feature
CPI_file_path = '/Users/wesamazaizeh/Desktop/Thinkful_Main_Course/Linear_Regression/local_unemployment_rate_2006to2009.csv'
CPI_df = pd.read_csv(CPI_file_path)

CPI_df2 = pd.DataFrame(columns=['year', 'month', 'value'])
years = range(2006, 2011)
months = range(1, 13)
for y, year in enumerate(years):
    for m, month in enumerate(months):
        ind = y*12+m
        CPI_df2.loc[ind, 'year'] = year
        CPI_df2.loc[ind, 'month'] = month
        CPI_df2.loc[ind, 'value'] = CPI_df.iloc[np.where(CPI_df['Year'] == 2006)[0], month][0]

house_price_df2 = pd.merge(house_price_df2, CPI_df2, left_on=['yrsold','mosold'], right_on=['year', 'month'], how='left').drop([ 'year', 'month'], axis=1)
house_price_df2.rename(columns={'value':'CPI'}, inplace=True)

house_price_df2.head()
# Out:
#    id  mssubclass mszoning  lotarea street lotshape landcontour utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   lotconfig landslope  ... miscval mosold yrsold saletype salecondition  \
# 0    Inside       Gtl  ...       0      2   2008       WD        Normal
# 1       FR2       Gtl  ...       0      5   2007       WD        Normal
# 2    Inside       Gtl  ...       0      9   2008       WD        Normal
# 3    Corner       Gtl  ...       0      2   2006       WD       Abnorml
# 4       FR2       Gtl  ...       0     12   2008       WD        Normal
#
#    saleprice  totalsf  interest  unemprate  CPI
# ...

# %% [markdown]
# ## Model preperation

# %%
# Distribution of target feature
sns.distplot(house_price_df2.saleprice)
plt.title("The distribution of house prices")
plt.xlabel("prices")
plt.ylabel("number of occurrence")
plt.show()

# %%
# log transform data to make it normal. Then, check normality of distribution
sns.distplot(np.log(house_price_df2.saleprice))
plt.title("Log transformed distribution of house prices")
plt.xlabel("Log prices")
plt.ylabel("Frequency")
plt.show()

# normality test

# %%
# # Try model with ALL features

data = house_price_df2[house_price_df2._get_numeric_data().columns.difference(['saleprice'])]
target = np.log(house_price_df2['saleprice'])

data_train, data_test, target_train, target_test = train_test_split(data, target, test_size = 0.2)

print("The number of observations in the training set is {}".format(data_train.shape[0]))
print("The number of observations in the test set is {}".format(data_test.shape[0]))

data_train = sm.add_constant(data_train)

# We fit an OLS model using statsmodels
results4 = sm.OLS(target_train, data_train).fit()

# We print the summary results

print(results4.summary())
# Out:
# The number of observations in the training set is 1070
# The number of observations in the test set is 268
#                             OLS Regression Results
# ...
# Dep. Variable:              saleprice   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     237.0
# Date:                Thu, 03 Oct 2019   Prob (F-statistic):               0.00
# Time:                        13:09:43   Log-Likelihood:                 665.78
# No. Observations:                1070   AIC:                            -1266.
# Df Residuals:                    1037   BIC:                            -1101.
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# Remove all non-significant features

to_keep = results4.pvalues.index[ results4.pvalues < 0.05]
to_keep = to_keep[1:]

data = house_price_df2[to_keep]
target = np.log(house_price_df2['saleprice'])

data_train, data_test, target_train, target_test = train_test_split(data, target, test_size = 0.2)

print("The number of observations in the training set is {}".format(data_train.shape[0]))
print("The number of observations in the test set is {}".format(data_test.shape[0]))

sm_data_train = sm.add_constant(data_train)

# We fit an OLS model using statsmodels
results5 = sm.OLS(target_train, sm_data_train).fit()

# We print the summary results

print(results5.summary())
# Out:
# The number of observations in the training set is 1070
# The number of observations in the test set is 268
#                             OLS Regression Results
# ...
# Dep. Variable:              saleprice   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                     347.4
# Date:                Thu, 03 Oct 2019   Prob (F-statistic):               0.00
# Time:                        16:42:11   Log-Likelihood:                 530.76
# No. Observations:                1070   AIC:                            -1026.
# Df Residuals:                    1052   BIC:                            -936.0
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# Laso, Ridge and ElasticNet cross-validation

from sklearn.linear_model import LassoCV, RidgeCV, ElasticNetCV

alphas = [np.power(10.0,p) for p in np.arange(-10,40,1)]

lasso_cv = LassoCV(alphas=alphas, cv=5)

lasso_cv.fit(data_train, target_train)

# We are making predictions here
target_preds_train = lasso_cv.predict(data_train)
target_preds_test = lasso_cv.predict(data_test)

print("Best alpha value is: {}".format(lasso_cv.alpha_))
print("R-squared of the model in training set is: {}".format(lasso_cv.score(data_train, target_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(lasso_cv.score(data_test, target_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(target_test, target_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(target_test, target_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(target_test, target_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((target_test - target_preds_test) / target_test)) * 100))
# Out:
# Best alpha value is: 1e-10
# R-squared of the model in training set is: 0.8488014699800248
# -----Test set statistics-----
# R-squared of the model in test set is: 0.8731218422425815
# Mean absolute error of the prediction is: 0.09577264196115892
# Mean squared error of the prediction is: 0.01712024779027797
# Root mean squared error of the prediction is: 0.13084436476317185
# Mean absolute percentage error of the prediction is: 0.8003716943864201

# %%
# Laso, Ridge and ElasticNet cross-validation

ridge_cv = RidgeCV(alphas=alphas, cv=5)

ridge_cv.fit(data_train, target_train)

# We are making predictions here
target_preds_train = ridge_cv.predict(data_train)
target_preds_test = ridge_cv.predict(data_test)

print("Best alpha value is: {}".format(ridge_cv.alpha_))
print("R-squared of the model in training set is: {}".format(ridge_cv.score(data_train, target_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(ridge_cv.score(data_test, target_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(target_test, target_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(target_test, target_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(target_test, target_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((target_test - target_preds_test) / target_test)) * 100))
# Out:
# Best alpha value is: 10.0
# R-squared of the model in training set is: 0.8486450359112164
# -----Test set statistics-----
# R-squared of the model in test set is: 0.8738066381184646
# Mean absolute error of the prediction is: 0.09529592846703325
# Mean squared error of the prediction is: 0.017027845163316013
# Root mean squared error of the prediction is: 0.1304907857410477
# Mean absolute percentage error of the prediction is: 0.7962331621717007

# %%
elasticnet_cv = ElasticNetCV(alphas=alphas, cv=5)

elasticnet_cv.fit(data_train, target_train)

# We are making predictions here
target_preds_train = elasticnet_cv.predict(data_train)
target_preds_test = elasticnet_cv.predict(data_test)

print("Best alpha value is: {}".format(elasticnet_cv.alpha_))
print("R-squared of the model in training set is: {}".format(elasticnet_cv.score(data_train, target_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(elasticnet_cv.score(data_test, target_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(target_test, target_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(target_test, target_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(target_test, target_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((target_test - target_preds_test) / target_test)) * 100))
# Out:
# Best alpha value is: 0.0001
# R-squared of the model in training set is: 0.8488000907589172
# -----Test set statistics-----
# R-squared of the model in test set is: 0.8732055301027584
# Mean absolute error of the prediction is: 0.09571176572250717
# Mean squared error of the prediction is: 0.01710895540608364
# Root mean squared error of the prediction is: 0.13080120567519107
# Mean absolute percentage error of the prediction is: 0.7998552182422313

# %%
# R-sqrt comparison
print('{:>15}{:>25}{:>25}{:>25}'.format('OLS', 'Lasso', 'Ridge', 'ElasticNet'))
print('R-sqr: {:>9.3f}{:>25.3f}{:>25.3f}{:>25.3f}'.format(results4.rsquared, elasticnet_cv.score(data_test, target_test), ridge_cv.score(data_test, target_test), elasticnet_cv.score(data_test, target_test)))
# Out:
#             OLS                    Lasso                    Ridge               ElasticNet
# R-sqr:     0.880                    0.873                    0.874                    0.873

# %% [markdown]
# ## Conclusion:
#
# - It seems that OLS performs the best.
# - Adding external economical data improved the model

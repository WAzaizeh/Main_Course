# %%
import numpy as np
import pandas as pd
from skew_autotransform import skew_autotransform
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf

import warnings
warnings.filterwarnings('ignore')

postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'weatherinszeged'

# %%
engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))
weather_df = pd.read_sql_query('select * from weatherinszeged',con=engine)

# no need for an open connection, as we're only doing a single query
engine.dispose()


weather_df.head(10)
# Out:
#                        date        summary preciptype  temperature  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy       rain     9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy       rain     9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy       rain     9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy       rain     8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy       rain     8.755556
# 5 2006-04-01 03:00:00+00:00  Partly Cloudy       rain     9.222222
# 6 2006-04-01 04:00:00+00:00  Partly Cloudy       rain     7.733333
# 7 2006-04-01 05:00:00+00:00  Partly Cloudy       rain     8.772222
# 8 2006-04-01 06:00:00+00:00  Partly Cloudy       rain    10.822222
# 9 2006-04-01 07:00:00+00:00  Partly Cloudy       rain    13.772222
#
#    apparenttemperature  humidity  windspeed  windbearing  visibility  \
# 0             7.388889      0.89    14.1197        251.0     15.8263
# 1             7.227778      0.86    14.2646        259.0     15.8263
# 2             9.377778      0.89     3.9284        204.0     14.9569
# 3             5.944444      0.83    14.1036        269.0     15.8263
# 4             6.977778      0.83    11.0446        259.0     15.8263
# 5             7.111111      0.85    13.9587        258.0     14.9569
# 6             5.522222      0.95    12.3648        259.0      9.9820
# 7             6.527778      0.89    14.1519        260.0      9.9820
# 8            10.822222      0.82    11.3183        259.0      9.9820
# 9            13.772222      0.72    12.5258        279.0      9.9820
#
#    loudcover  pressure                       dailysummary
# 0        0.0   1015.13  Partly cloudy throughout the day.
# 1        0.0   1015.63  Partly cloudy throughout the day.
# 2        0.0   1015.94  Partly cloudy throughout the day.
# 3        0.0   1016.41  Partly cloudy throughout the day.
# 4        0.0   1016.51  Partly cloudy throughout the day.
# 5        0.0   1016.66  Partly cloudy throughout the day.
# 6        0.0   1016.72  Partly cloudy throughout the day.
# 7        0.0   1016.84  Partly cloudy throughout the day.
# 8        0.0   1017.37  Partly cloudy throughout the day.
# 9        0.0   1017.22  Partly cloudy throughout the day.

# %%
# check for skewness and normality
weather_df2 = skew_autotransform.skew_autotransform(weather_df.copy(deep=True), plot = True, exclude=('date','summary','preciptype', 'dailysummary'))
# Out:
#  ------------------------------------------------------
#
#  NO TRANSFORMATION APPLIED FOR 'temperature' . Skewness = 0.09
#  ------------------------------------------------------
#
#  NO TRANSFORMATION APPLIED FOR 'apparenttemperature' . Skewness = -0.06
#  ------------------------------------------------------
#
#  NO TRANSFORMATION APPLIED FOR 'humidity' . Skewness = -0.72
#  ------------------------------------------------------
#
#  'windspeed' had 'positive' skewness of 1.11
#
#  Transformation yielded skewness of -0.00
#  ------------------------------------------------------
#
#  NO TRANSFORMATION APPLIED FOR 'windbearing' . Skewness = -0.15
#  ------------------------------------------------------
#
#  NO TRANSFORMATION APPLIED FOR 'visibility' . Skewness = -0.50
#  ------------------------------------------------------
#
#  NO TRANSFORMATION APPLIED FOR 'loudcover' . Skewness = 0.00
#  ------------------------------------------------------
#
#  'pressure' had 'negative' skewness of -8.42
#
#  Transformation yielded skewness of -6.90

# %%
# Feature engineering for model
weather_df3 = weather_df.loc[:,('humidity', 'windspeed')]
weather_df3['humidity3'] = weather_df3['humidity'] ** 2
weather_df3['windspeed2'] = np.sqrt(weather_df3['windspeed'])
weather_df3['humidity_windspeed'] = weather_df3['humidity'] * weather_df3['windspeed']
weather_df3['apparentdifference'] =  weather_df['apparenttemperature'] - weather_df['temperature']

corr = weather_df3.corr()
corr.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
#     #T_17af9d58_c759_11e9_847e_109add48ac16row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row0_col1 {
#             background-color:  #2b73b3;
#             color:  #000000;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row0_col2 {
#             background-color:  #6d0220;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row0_col3 {
#             background-color:  #2b73b3;
#             color:  #000000;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row0_col4 {
#             background-color:  #f2f5f6;
#             color:  #000000;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row0_col5 {
#             background-color:  #4695c4;
#             color:  #000000;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row1_col0 {
#             background-color:  #08366a;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row1_col2 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row1_col3 {
#             background-color:  #790622;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row1_col4 {
#             background-color:  #a21328;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row1_col5 {
#             background-color:  #1f63a8;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row2_col0 {
#             background-color:  #6d0220;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row2_col1 {
#             background-color:  #276eb0;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row2_col3 {
#             background-color:  #276eb0;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row2_col4 {
#             background-color:  #ecf2f5;
#             color:  #000000;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row2_col5 {
#             background-color:  #4695c4;
#             color:  #000000;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row3_col0 {
#             background-color:  #073467;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row3_col1 {
#             background-color:  #790622;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row3_col2 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row3_col3 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row3_col4 {
#             background-color:  #ab162a;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row3_col5 {
#             background-color:  #1e61a5;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row4_col0 {
#             background-color:  #b6d7e8;
#             color:  #000000;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row4_col1 {
#             background-color:  #a81529;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row4_col2 {
#             background-color:  #a9d1e5;
#             color:  #000000;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row4_col3 {
#             background-color:  #b1182b;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row4_col4 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row4_col5 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row5_col0 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row5_col1 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row5_col2 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row5_col3 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row5_col4 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_17af9d58_c759_11e9_847e_109add48ac16row5_col5 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }</style><table id="T_17af9d58_c759_11e9_847e_109add48ac16" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >humidity</th>        <th class="col_heading level0 col1" >windspeed</th>        <th class="col_heading level0 col2" >humidity3</th>        <th class="col_heading level0 col3" >windspeed2</th>        <th class="col_heading level0 col4" >humidity_windspeed</th>        <th class="col_heading level0 col5" >apparentdifference</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17af9d58_c759_11e9_847e_109add48ac16level0_row0" class="row_heading level0 row0" >humidity</th>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row0_col1" class="data row0 col1" >-0.224951</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row0_col2" class="data row0 col2" >0.989105</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row0_col3" class="data row0 col3" >-0.230762</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row0_col4" class="data row0 col4" >0.200929</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row0_col5" class="data row0 col5" >-0.242212</td>
#             </tr>
#             <tr>
#                         <th id="T_17af9d58_c759_11e9_847e_109add48ac16level0_row1" class="row_heading level0 row1" >windspeed</th>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row1_col0" class="data row1 col0" >-0.224951</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row1_col2" class="data row1 col2" >-0.24146</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row1_col3" class="data row1 col3" >0.96599</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row1_col4" class="data row1 col4" >0.875213</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row1_col5" class="data row1 col5" >-0.411943</td>
#             </tr>
#             <tr>
#                         <th id="T_17af9d58_c759_11e9_847e_109add48ac16level0_row2" class="row_heading level0 row2" >humidity3</th>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row2_col0" class="data row2 col0" >0.989105</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row2_col1" class="data row2 col1" >-0.24146</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row2_col3" class="data row2 col3" >-0.247196</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row2_col4" class="data row2 col4" >0.1727</td>
#                         <td id="T_17af9d58_c759_11e9_847e_109add48ac16row2_col5" class="data row2 col5" >-0.239443</td>
#             </tr>
#             <tr>
#                         <th id="

# %%
# visualize differences in temperature accross the different explanatory variables
plt.figure(figsize=(30,30))

cols = weather_df3.columns[:-1]
for index, column in enumerate(cols):
    plt.subplot(3,2,index+1)
    sns.scatterplot(x=column, y='apparentdifference', data=weather_df3)
    plt.title('Apparent temperature difference wrt. {}'.format(column), size=26)
    plt.ylabel('Apparent temperature difference', size=26)
    plt.xlabel(column, size=26)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## SciKit Learn model

# %%
target = weather_df3['apparentdifference']
data = weather_df3[cols]

# Initialize linear regression model
lrm = linear_model.LinearRegression()

# fit method estimates the coefficients using OLS
lrm.fit(data, target)

# Inspect the results.
print('\nCoefficients: \n', lrm.coef_)
print('\nIntercept: \n', lrm.intercept_)
# Out:
# Coefficients:
#  [-3.02918594 -0.11929075]
#
# Intercept:
#  2.4381054151877173

# %% [markdown]
# Estimated model:
#
# $$ Apparent temperature difference = 2.44 -3.03*Humidity -0.12*Windspeed\qquad$$

# %% [markdown]
# ## StatsModels model

# %%
sm_data = sm.add_constant(data)

results = sm.OLS(target, sm_data).fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     apparentdifference   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                 1.949e+04
# Date:                Sun, 25 Aug 2019   Prob (F-statistic):               0.00
# Time:                        07:21:21   Log-Likelihood:            -1.7046e+05
# No. Observations:               96453   AIC:                         3.409e+05
# Df Residuals:                   96450   BIC:                         3.409e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.4381      0.021    115.948      0.000       2.397       2.479
# humidity      -3.0292      0.024   -126.479      0.000      -3.076      -2.982
# windspeed     -0.1193      0.001   -176.164      0.000      -0.121      -0.118
# ==============================================================================
# Omnibus:                     3935.747   Durbin-Watson:                   0.267
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4613.311
# Skew:                          -0.478   Prob(JB):                         0.00
# Kurtosis:                       3.484   Cond. No.                         88.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Assumptions check:
#
# ### 1. linearity of the model in its coefficients
#
# ### 2. the error term should be zero on average

# %%
predictions = lrm.predict(data)
errors = target - predictions
print("Mean of the errors in model is: {:.2}".format(np.mean(errors)))
# Out:
# Mean of the errors in model is: 4.9e-16

# %% [markdown]
# The average of the model's error is effectively zero.

# %% [markdown]
# ### 3. homoscedasticity

# %%
# visualizing homoscedasticity
plt.figure(figsize=(12,8))
sns.scatterplot(x=predictions, y=errors)
plt.xlabel('Predicted')
plt.ylabel('Residual')
plt.axhline(y=0)
plt.title('Residual vs. Predicted')
plt.show()

# %%
# statistical tests for homoscedasticity
from scipy.stats import bartlett
from scipy.stats import levene

bart_stats = bartlett(predictions, errors)
lev_stats = levene(predictions, errors)

print("Bartlett test statistic value is {0:3g} and p value is {1:.3g}".format(bart_stats[0], bart_stats[1]))
print("Levene test statistic value is {0:3g} and p value is {1:.3g}".format(lev_stats[0], lev_stats[1]))
# Out:
# Bartlett test statistic value is 19150.8 and p value is 0
# Levene test statistic value is 14884.8 and p value is 0

# %% [markdown]
# The p-values of both tests are lower than 0.05. The test results reject the null hypothesis which means our errors are heteroscedastic.

# %% [markdown]
# ### 4. low multicollinearity

# %%
corr = weather_df3.corr()
corr.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
#     #T_b65eff7a_c743_11e9_a8d1_109add48ac16row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_b65eff7a_c743_11e9_a8d1_109add48ac16row0_col1 {
#             background-color:  #2b73b3;
#             color:  #000000;
#         }    #T_b65eff7a_c743_11e9_a8d1_109add48ac16row0_col2 {
#             background-color:  #276eb0;
#             color:  #f1f1f1;
#         }    #T_b65eff7a_c743_11e9_a8d1_109add48ac16row1_col0 {
#             background-color:  #08366a;
#             color:  #f1f1f1;
#         }    #T_b65eff7a_c743_11e9_a8d1_109add48ac16row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_b65eff7a_c743_11e9_a8d1_109add48ac16row1_col2 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_b65eff7a_c743_11e9_a8d1_109add48ac16row2_col0 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_b65eff7a_c743_11e9_a8d1_109add48ac16row2_col1 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_b65eff7a_c743_11e9_a8d1_109add48ac16row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }</style><table id="T_b65eff7a_c743_11e9_a8d1_109add48ac16" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >humidity</th>        <th class="col_heading level0 col1" >windspeed</th>        <th class="col_heading level0 col2" >apparentdifference</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b65eff7a_c743_11e9_a8d1_109add48ac16level0_row0" class="row_heading level0 row0" >humidity</th>
#                         <td id="T_b65eff7a_c743_11e9_a8d1_109add48ac16row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b65eff7a_c743_11e9_a8d1_109add48ac16row0_col1" class="data row0 col1" >-0.224951</td>
#                         <td id="T_b65eff7a_c743_11e9_a8d1_109add48ac16row0_col2" class="data row0 col2" >-0.242212</td>
#             </tr>
#             <tr>
#                         <th id="T_b65eff7a_c743_11e9_a8d1_109add48ac16level0_row1" class="row_heading level0 row1" >windspeed</th>
#                         <td id="T_b65eff7a_c743_11e9_a8d1_109add48ac16row1_col0" class="data row1 col0" >-0.224951</td>
#                         <td id="T_b65eff7a_c743_11e9_a8d1_109add48ac16row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_b65eff7a_c743_11e9_a8d1_109add48ac16row1_col2" class="data row1 col2" >-0.411943</td>
#             </tr>
#             <tr>
#                         <th id="T_b65eff7a_c743_11e9_a8d1_109add48ac16level0_row2" class="row_heading level0 row2" >apparentdifference</th>
#                         <td id="T_b65eff7a_c743_11e9_a8d1_109add48ac16row2_col0" class="data row2 col0" >-0.242212</td>
#                         <td id="T_b65eff7a_c743_11e9_a8d1_109add48ac16row2_col1" class="data row2 col1" >-0.411943</td>
#                         <td id="T_b65eff7a_c743_11e9_a8d1_109add48ac16row2_col2" class="data row2 col2" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Low correlation between explanatory features

# %% [markdown]
# ### 5. error terms should be uncorrelated with one another

# %%
plt.plot(errors)
plt.show()

# %%
acf_data = acf(errors)

plt.plot(acf_data[1:])
plt.show()

# %% [markdown]
# ### 6. features shouldn't be correlated with the errors

# %% [markdown]
# ## Are the estimated coefficients statistically significant?
#
# both coefficients are statistically significant according to the model's summary.

# %% [markdown]
# ## Are the signs of the estimated coefficients in line with your previous expectations?
# Yes, both humidity and wind speed decrease the apparent temperature difference.

# %% [markdown]
# # Split model into two based on bimodal apparent temperature distribution

# %%
# apparent temp distribution
sns.distplot(weather_df2['apparenttemperature'])
plt.vlines(x=9, ymin=0, ymax=0.04)
plt.show()

weather_df_cold = weather_df2[weather_df2['apparenttemperature'] < 9]
weather_df_warm = weather_df2[weather_df2['apparenttemperature'] >= 9]

plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sns.distplot(weather_df_cold['apparenttemperature'])
plt.subplot(1,2,2)
sns.distplot(weather_df_warm['apparenttemperature'])
plt.show()

# %%
# Feature engineering for split model
weather_df2_cold = weather_df_cold.loc[:,('humidity', 'windspeed')]
weather_df2_cold['apparentdifference'] =  weather_df_cold['apparenttemperature'] - weather_df_cold['temperature']

weather_df2_warm = weather_df_warm.loc[:,('humidity', 'windspeed')]
weather_df2_warm['apparentdifference'] =  weather_df_warm['apparenttemperature'] - weather_df_warm['temperature']


corr = weather_df2_cold.corr()
corr.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
#     #T_b80159b4_c868_11e9_9a0c_109add48ac16row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_b80159b4_c868_11e9_9a0c_109add48ac16row0_col1 {
#             background-color:  #7eb8d7;
#             color:  #000000;
#         }    #T_b80159b4_c868_11e9_9a0c_109add48ac16row0_col2 {
#             background-color:  #fce2d2;
#             color:  #000000;
#         }    #T_b80159b4_c868_11e9_9a0c_109add48ac16row1_col0 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_b80159b4_c868_11e9_9a0c_109add48ac16row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_b80159b4_c868_11e9_9a0c_109add48ac16row1_col2 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_b80159b4_c868_11e9_9a0c_109add48ac16row2_col0 {
#             background-color:  #d5e7f1;
#             color:  #000000;
#         }    #T_b80159b4_c868_11e9_9a0c_109add48ac16row2_col1 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_b80159b4_c868_11e9_9a0c_109add48ac16row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }</style><table id="T_b80159b4_c868_11e9_9a0c_109add48ac16" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >humidity</th>        <th class="col_heading level0 col1" >windspeed</th>        <th class="col_heading level0 col2" >apparentdifference</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b80159b4_c868_11e9_9a0c_109add48ac16level0_row0" class="row_heading level0 row0" >humidity</th>
#                         <td id="T_b80159b4_c868_11e9_9a0c_109add48ac16row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b80159b4_c868_11e9_9a0c_109add48ac16row0_col1" class="data row0 col1" >-0.326973</td>
#                         <td id="T_b80159b4_c868_11e9_9a0c_109add48ac16row0_col2" class="data row0 col2" >0.218489</td>
#             </tr>
#             <tr>
#                         <th id="T_b80159b4_c868_11e9_9a0c_109add48ac16level0_row1" class="row_heading level0 row1" >windspeed</th>
#                         <td id="T_b80159b4_c868_11e9_9a0c_109add48ac16row1_col0" class="data row1 col0" >-0.326973</td>
#                         <td id="T_b80159b4_c868_11e9_9a0c_109add48ac16row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_b80159b4_c868_11e9_9a0c_109add48ac16row1_col2" class="data row1 col2" >-0.836209</td>
#             </tr>
#             <tr>
#                         <th id="T_b80159b4_c868_11e9_9a0c_109add48ac16level0_row2" class="row_heading level0 row2" >apparentdifference</th>
#                         <td id="T_b80159b4_c868_11e9_9a0c_109add48ac16row2_col0" class="data row2 col0" >0.218489</td>
#                         <td id="T_b80159b4_c868_11e9_9a0c_109add48ac16row2_col1" class="data row2 col1" >-0.836209</td>
#                         <td id="T_b80159b4_c868_11e9_9a0c_109add48ac16row2_col2" class="data row2 col2" >1</td>
#             </tr>
#     </tbody></table>

# %%
# visualize differences in apparent cold temps
plt.figure(figsize=(30,30))

cols = weather_df2_cold.columns[:-1]
for index, column in enumerate(cols):
    plt.subplot(3,2,index+1)
    sns.scatterplot(x=column, y='apparentdifference', data=weather_df2_cold)
    plt.title('Apparent temperature difference wrt. {}'.format(column), size=26)
    plt.ylabel('Apparent temperature difference', size=26)
    plt.xlabel(column, size=26)

plt.tight_layout()
plt.show()

# %%
# visualize differences in apparent warm temps
plt.figure(figsize=(30,30))

cols = weather_df2_warm.columns[:-1]
for index, column in enumerate(cols):
    plt.subplot(3,2,index+1)
    sns.scatterplot(x=column, y='apparentdifference', data=weather_df2_warm)
    plt.title('Apparent temperature difference wrt. {}'.format(column), size=26)
    plt.ylabel('Apparent temperature difference', size=26)
    plt.xlabel(column, size=26)

plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x=np.log(weather_df2_cold['windspeed']), y='apparentdifference', data=weather_df2_cold)
plt.show()

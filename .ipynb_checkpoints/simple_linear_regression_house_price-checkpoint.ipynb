# %% [markdown]
# ## Preliminary data exploration
#
# To choose the features we use in our first model, we do a brief exploratory analysis here.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import statsmodels.api as sm

import warnings
warnings.filterwarnings('ignore')

postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'houseprices'

# %%
engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))
houseprice_df = pd.read_sql_query('select * from houseprices',con=engine)

# no need for an open connection, as we're only doing a single query
engine.dispose()


houseprice_df.head(10)
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
# 5   6          50       RL         85.0    14115   Pave  None      IR1
# 6   7          20       RL         75.0    10084   Pave  None      Reg
# 7   8          60       RL          NaN    10382   Pave  None      IR1
# 8   9          50       RM         51.0     6120   Pave  None      Reg
# 9  10         190       RL         50.0     7420   Pave  None      Reg
#
#   landcontour utilities  ... poolarea poolqc  fence miscfeature miscval  \
# 0         Lvl    AllPub  ...        0   None   None        None       0
# 1         Lvl    AllPub  ...        0   None   None        None       0
# 2         Lvl    AllPub  ...        0   None   None        None       0
# 3         Lvl    AllPub  ...        0   None   None        None       0
# 4         Lvl    AllPub  ...        0   None   None        None       0
# 5         Lvl    AllPub  ...        0   None  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0   None   None        None       0
# 7         Lvl    AllPub  ...        0   None   None        Shed     350
# 8         Lvl    AllPub  ...        0   None   None        None       0
# 9         Lvl    AllPub  ...        0   None   None        None       0
#
#   mosold yrsold  saletype  salecondition  saleprice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %%
houseprice_df.describe()
# Out:
#                 id   mssubclass  lotfrontage        lotarea  overallqual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        overallcond    yearbuilt  yearremodadd   masvnrarea   bsmtfinsf1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         wooddecksf  openporchsf  enclosedporch  threessnporch  screenporch  \
# count  1460.000000  1460.000000    1460.000000    1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110       3.409589    15.060959
# std     125.338794    66.256028      61.119149      29.317331    55.757415
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       0.000000     0.000000       0.000000       0.000000     0.000000
# 50%       0.000000    25.000000       0.000000       0.000000     0.000000
# 75%     168.000000    68.000000       0.000000       0.000000     0.000000
# max     857.000000   547.000000     552.000000     508.000000   480.000000
#
#           poolarea       miscval       mosold       yrsold      saleprice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ### Handling missing data

# %%
houseprice_df.isnull().sum()/houseprice_df.shape[0]*100
# Out:
# id                0.000000
# mssubclass        0.000000
# mszoning          0.000000
# lotfrontage      17.739726
# lotarea           0.000000
# street            0.000000
# alley            93.767123
# lotshape          0.000000
# landcontour       0.000000
# utilities         0.000000
# lotconfig         0.000000
# landslope         0.000000
# neighborhood      0.000000
# condition1        0.000000
# condition2        0.000000
# bldgtype          0.000000
# housestyle        0.000000
# overallqual       0.000000
# overallcond       0.000000
# yearbuilt         0.000000
# yearremodadd      0.000000
# roofstyle         0.000000
# roofmatl          0.000000
# exterior1st       0.000000
# exterior2nd       0.000000
# masvnrtype        0.547945
# masvnrarea        0.547945
# exterqual         0.000000
# extercond         0.000000
# foundation        0.000000
#                    ...
# bedroomabvgr      0.000000
# kitchenabvgr      0.000000
# kitchenqual       0.000000
# totrmsabvgrd      0.000000
# functional        0.000000
# fireplaces        0.000000
# fireplacequ      47.260274
# garagetype        5.547945
# garageyrblt       5.547945
# garagefinish      5.547945
# garagecars        0.000000
# garagearea        0.000000
# garagequal        5.547945
# garagecond        5.547945
# paveddrive        0.000000
# wooddecksf        0.000000
# openporchsf       0.000000
# enclosedporch     0.000000
# threessnporch     0.000000
# screenporch       0.000000
# poolarea          0.000000
# poolqc           99.520548
# fence            80.753425
# miscfeature      96.301370
# miscval           0.000000
# mosold            0.000000
# yrsold            0.000000
# saletype          0.000000
# salecondition     0.000000
# saleprice         0.000000
# Length: 81, dtype: float64

# %%
# drop columns with more than 10% missing values
houseprice_df2 = houseprice_df.loc[:, houseprice_df.isnull().sum()/houseprice_df.shape[0] < 0.1]
print('{} columns dropped'.format(houseprice_df.shape[1] - houseprice_df2.shape[1]))
# Out:
# 6 columns dropped

# %%
houseprice_df2.isnull().sum()/houseprice_df2.shape[0]*100
# Out:
# id               0.000000
# mssubclass       0.000000
# mszoning         0.000000
# lotarea          0.000000
# street           0.000000
# lotshape         0.000000
# landcontour      0.000000
# utilities        0.000000
# lotconfig        0.000000
# landslope        0.000000
# neighborhood     0.000000
# condition1       0.000000
# condition2       0.000000
# bldgtype         0.000000
# housestyle       0.000000
# overallqual      0.000000
# overallcond      0.000000
# yearbuilt        0.000000
# yearremodadd     0.000000
# roofstyle        0.000000
# roofmatl         0.000000
# exterior1st      0.000000
# exterior2nd      0.000000
# masvnrtype       0.547945
# masvnrarea       0.547945
# exterqual        0.000000
# extercond        0.000000
# foundation       0.000000
# bsmtqual         2.534247
# bsmtcond         2.534247
#                    ...
# bsmtfullbath     0.000000
# bsmthalfbath     0.000000
# fullbath         0.000000
# halfbath         0.000000
# bedroomabvgr     0.000000
# kitchenabvgr     0.000000
# kitchenqual      0.000000
# totrmsabvgrd     0.000000
# functional       0.000000
# fireplaces       0.000000
# garagetype       5.547945
# garageyrblt      5.547945
# garagefinish     5.547945
# garagecars       0.000000
# garagearea       0.000000
# garagequal       5.547945
# garagecond       5.547945
# paveddrive       0.000000
# wooddecksf       0.000000
# openporchsf      0.000000
# enclosedporch    0.000000
# threessnporch    0.000000
# screenporch      0.000000
# poolarea         0.000000
# miscval          0.000000
# mosold           0.000000
# yrsold           0.000000
# saletype         0.000000
# salecondition    0.000000
# saleprice        0.000000
# Length: 75, dtype: float64

# %%
sns.distplot(houseprice_df2.isnull().sum(axis=1), kde=False)
plt.title('Histogram of empty values per row')
plt.xlabel('Number of NAs')
plt.show()

# %%
# drop rows with more than 2 missing values

houseprice_df3 = houseprice_df2.loc[houseprice_df2.isnull().sum(axis=1) < 3 ,:]
print('{} out of {} rows dropped'.format(houseprice_df2.shape[0] - houseprice_df3.shape[0], houseprice_df2.shape[0]))
# Out:
# 111 out of 1460 rows dropped

# %% [markdown]
# ### Features of interest

# %%
# Distribution of target feature
sns.distplot(houseprice_df3.saleprice)
plt.title("The distribution of house prices")
plt.xlabel("prices")
plt.ylabel("number of occurrence")
plt.show()

# %%
# correaltion matrix for the 10 most correlated features
corr = houseprice_df3.corr()
corr_features = np.abs(corr['saleprice']).sort_values(ascending=False).index[:11]
corr = houseprice_df[corr_features[1:]].corr()
# Select upper triangle of correlation matrix
upper = corr.where(np.triu(np.ones(np.abs(corr.shape)), k=1).astype(np.bool)) 
# Find features with correlation greater than 0.75
to_drop = [column for column in upper.columns if any(upper[column] > 0.75)]
# remove features that have high correlation
corr = corr.drop(to_drop, axis=1).drop(to_drop, axis=0)
to_keep = corr.columns.values.tolist()
to_keep.append('saleprice')
corr = houseprice_df3[to_keep].corr()
corr.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
#     #T_cff05b0c_cf4f_11e9_9101_109add48ac16row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row0_col1 {
#             background-color:  #f6f7f7;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row0_col2 {
#             background-color:  #7bb6d6;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row0_col3 {
#             background-color:  #9dcbe1;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row0_col4 {
#             background-color:  #a5cee3;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row0_col5 {
#             background-color:  #ecf2f5;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row0_col6 {
#             background-color:  #d4e6f1;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row0_col7 {
#             background-color:  #fbe4d6;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row1_col0 {
#             background-color:  #4c99c6;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row1_col2 {
#             background-color:  #1a5899;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row1_col3 {
#             background-color:  #d7e8f1;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row1_col4 {
#             background-color:  #d4e6f1;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row1_col5 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row1_col6 {
#             background-color:  #124984;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row1_col7 {
#             background-color:  #d8e9f1;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row2_col0 {
#             background-color:  #4f9bc7;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row2_col1 {
#             background-color:  #bbdaea;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row2_col3 {
#             background-color:  #75b2d4;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row2_col4 {
#             background-color:  #569fc9;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row2_col5 {
#             background-color:  #d7e8f1;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row2_col6 {
#             background-color:  #8ac0db;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row2_col7 {
#             background-color:  #84bcd9;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row3_col0 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row3_col1 {
#             background-color:  #e4eef4;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row3_col2 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row3_col3 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row3_col4 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row3_col5 {
#             background-color:  #1d5fa2;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row3_col6 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row3_col7 {
#             background-color:  #4695c4;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row4_col0 {
#             background-color:  #3e8cbf;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row4_col1 {
#             background-color:  #f9ebe3;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row4_col2 {
#             background-color:  #2a71b2;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row4_col3 {
#             background-color:  #3a87bd;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row4_col4 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row4_col5 {
#             background-color:  #bbdaea;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row4_col6 {
#             background-color:  #8ac0db;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row4_col7 {
#             background-color:  #2b73b3;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row5_col0 {
#             background-color:  #3a87bd;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row5_col1 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row5_col2 {
#             background-color:  #327cb7;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row5_col3 {
#             background-color:  #0d3f76;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row5_col4 {
#             background-color:  #3e8cbf;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row5_col5 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row5_col6 {
#             background-color:  #f7f6f6;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row5_col7 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row6_col0 {
#             background-color:  #2b73b3;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row6_col1 {
#             background-color:  #2369ad;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row6_col2 {
#             background-color:  #0f437b;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row6_col3 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row6_col4 {
#             background-color:  #2f79b5;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row6_col5 {
#             background-color:  #f9eee7;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row6_col6 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row6_col7 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row7_col0 {
#             background-color:  #fcdfcf;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row7_col1 {
#             background-color:  #f9c4a9;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row7_col2 {
#             background-color:  #b8d8e9;
#             color:  #000000;
#         }    #T_cff05b0c_cf4f_11e9_9101_109add48ac16row7_col3 {
#             background-color:  #eff3f5;
#             color:  #000000;

# %%
# visualize differences in sale price among the different features of interest
plt.figure(figsize=(30,50))

for index, column in enumerate(to_keep):
    plt.subplot(4,2,index+1)
    if(houseprice_df3[column].nunique() < 10):
        sns.barplot(x=column, y='saleprice', data=houseprice_df3)
        plt.title('Average saleprice wrt. {}'.format(column), size=26)
        plt.ylabel('Average sale price', size=26)
        plt.xlabel(column, size=26)
    else:
        sns.scatterplot(x=column, y='saleprice', data=houseprice_df3)
        plt.title('Saleprice wrt. {}'.format(column), size=26)
        plt.ylabel('Sale price', size=26)
        plt.xlabel(column, size=26)

plt.tight_layout()

plt.show()

# %% [markdown]
# - As can be seen in the graphs, these features show some varying trend wrt. sale price

# %% [markdown]
# ## An initial model for house sale prices
#
# Simple linear regression model and estimate it using OLS. Will use both scikit-learn and statsmodels for the sake of practice.

# %%
#SciKit Learn Model

target = houseprice_df3['saleprice']
data = houseprice_df3[to_keep[:-1]]

# Initialize linear regression model
lrm = linear_model.LinearRegression()

# fit method estimates the coefficients using OLS
lrm.fit(data, target)

# Inspect the results.
print('\nCoefficients: \n', lrm.coef_)
print('\nIntercept: \n', lrm.intercept_)
# Out:
# Coefficients:
#  [ 21576.34001153     52.96854906  16966.07961158     32.20423775
#  -10908.42517197    298.72731956    277.2473634 ]
#
# Intercept:
#  -1221267.0772255561

# %% [markdown]
# Estimated model:
#
# $$ sale price = -1221267.08 + 21576.34*overallqual + 52.97*grlivarea +  16966.08*garagecars + 32.20*firstflrsf + -10908.41*fullbath + 298.73*yearbuilt + 277.25*yearremodadd\qquad$$

# %%
# StatsModels model

sm_data = sm.add_constant(data)

results = sm.OLS(target, sm_data).fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     617.9
# Date:                Wed, 04 Sep 2019   Prob (F-statistic):               0.00
# Time:                        16:08:55   Log-Likelihood:                -16155.
# No. Observations:                1349   AIC:                         3.233e+04
# Df Residuals:                    1341   BIC:                         3.237e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1.221e+06   1.38e+05     -8.862      0.000   -1.49e+06   -9.51e+05
# overallqual   2.158e+04   1272.381     16.957      0.000    1.91e+04    2.41e+04
# grlivarea       52.9685      3.267     16.211      0.000      46.559      59.378
# garagecars    1.697e+04   2276.687      7.452      0.000    1.25e+04    2.14e+04
# firstflrsf      32.2042      3.397      9.481      0.000      25.541      38.868
# fullbath     -1.091e+04   2846.004     -3.833      0.000   -1.65e+04   -5325.320
# yearbuilt      298.7273     53.722      5.561      0.000     193.338     404.116
# yearremodadd   277.2474     70.053      3.958      0.000     139.822     414.673
# ==============================================================================
# Omnibus:                      392.557   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37674.806
# Skew:                          -0.218   Prob(JB):                         0.00
# Kurtosis:                      28.886   Cond. No.                     4.49e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Check for all of the assumptions above and discuss the implications if some of the assumptions are not met.

# %% [markdown]
# ### Assumption one: linearity of the model in its coefficients
# Satisfied by design

# %% [markdown]
# ### Assumption two: the error term should be zero on average

# %%
predictions = lrm.predict(data)
errors = target - predictions
print("Mean of the errors in model is: {:.2}".format(np.mean(errors)))
# Out:
# Mean of the errors in model is: -1e-10

# %% [markdown]
# The average of the model's error is effectively zero.

# %% [markdown]
# ### Assumption three: homoscedasticity

# %%
# visualizing homoscedasticity
plt.figure(figsize=(12,8))
sns.scatterplot(x=predictions, y=errors)
plt.xlabel('Predicted')
plt.ylabel('Residual')
plt.axhline(y=0)
plt.title('Residual vs. Predicted')
plt.show()

# %%
# statistical tests for homoscedasticity
from scipy.stats import bartlett
from scipy.stats import levene

bart_stats = bartlett(predictions, errors)
lev_stats = levene(predictions, errors)

print("Bartlett test statistic value is {0:3g} and p value is {1:.3g}".format(bart_stats[0], bart_stats[1]))
print("Levene test statistic value is {0:3g} and p value is {1:.3g}".format(lev_stats[0], lev_stats[1]))
# Out:
# Bartlett test statistic value is 437.723 and p value is 3.39e-97
# Levene test statistic value is 448.642 and p value is 3.11e-92

# %% [markdown]
# The p-values of both tests are lower than 0.05. So, the test results reject the null hypothesis which means our errors are heteroscedastic.
# This could be due to ouliers in the data or lack of normality.

# %% [markdown]
# ### Assumption four: low multicollinearity

# %%
corr = houseprice_df3[to_keep].corr()
corr.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
#     #T_d302e940_cf4f_11e9_90b7_109add48ac16row0_col0 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row0_col1 {
#             background-color:  #f6f7f7;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row0_col2 {
#             background-color:  #7bb6d6;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row0_col3 {
#             background-color:  #9dcbe1;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row0_col4 {
#             background-color:  #a5cee3;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row0_col5 {
#             background-color:  #ecf2f5;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row0_col6 {
#             background-color:  #d4e6f1;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row0_col7 {
#             background-color:  #fbe4d6;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row1_col0 {
#             background-color:  #4c99c6;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row1_col1 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row1_col2 {
#             background-color:  #1a5899;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row1_col3 {
#             background-color:  #d7e8f1;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row1_col4 {
#             background-color:  #d4e6f1;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row1_col5 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row1_col6 {
#             background-color:  #124984;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row1_col7 {
#             background-color:  #d8e9f1;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row2_col0 {
#             background-color:  #4f9bc7;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row2_col1 {
#             background-color:  #bbdaea;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row2_col2 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row2_col3 {
#             background-color:  #75b2d4;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row2_col4 {
#             background-color:  #569fc9;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row2_col5 {
#             background-color:  #d7e8f1;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row2_col6 {
#             background-color:  #8ac0db;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row2_col7 {
#             background-color:  #84bcd9;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row3_col0 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row3_col1 {
#             background-color:  #e4eef4;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row3_col2 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row3_col3 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row3_col4 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row3_col5 {
#             background-color:  #1d5fa2;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row3_col6 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row3_col7 {
#             background-color:  #4695c4;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row4_col0 {
#             background-color:  #3e8cbf;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row4_col1 {
#             background-color:  #f9ebe3;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row4_col2 {
#             background-color:  #2a71b2;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row4_col3 {
#             background-color:  #3a87bd;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row4_col4 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row4_col5 {
#             background-color:  #bbdaea;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row4_col6 {
#             background-color:  #8ac0db;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row4_col7 {
#             background-color:  #2b73b3;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row5_col0 {
#             background-color:  #3a87bd;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row5_col1 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row5_col2 {
#             background-color:  #327cb7;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row5_col3 {
#             background-color:  #0d3f76;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row5_col4 {
#             background-color:  #3e8cbf;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row5_col5 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row5_col6 {
#             background-color:  #f7f6f6;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row5_col7 {
#             background-color:  #063264;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row6_col0 {
#             background-color:  #2b73b3;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row6_col1 {
#             background-color:  #2369ad;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row6_col2 {
#             background-color:  #0f437b;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row6_col3 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row6_col4 {
#             background-color:  #2f79b5;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row6_col5 {
#             background-color:  #f9eee7;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row6_col6 {
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row6_col7 {
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row7_col0 {
#             background-color:  #fcdfcf;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row7_col1 {
#             background-color:  #f9c4a9;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row7_col2 {
#             background-color:  #b8d8e9;
#             color:  #000000;
#         }    #T_d302e940_cf4f_11e9_90b7_109add48ac16row7_col3 {
#             background-color:  #eff3f5;
#             color:  #000000;

# %% [markdown]
# Highly correlated features were dropped during model preperation. Therefore, this assumption is satisfied.

# %% [markdown]
# ### Assumption five: error terms should be uncorrelated with one another

# %%
plt.plot(errors)
plt.show()

# %%
from statsmodels.tsa.stattools import acf

acf_data = acf(errors)

plt.plot(acf_data[1:])
plt.show()

# %% [markdown]
# So, the autocorrelation between the errors of the model is indeed  low (ranging between -0.06 and 0.10).

# %% [markdown]
# ### Assumption six: features shouldn't be correlated with the errors

# %% [markdown]
# ## Module 19.4 assignment 3:
# ### Which features are statistically significant, and which are not?

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     617.9
# Date:                Wed, 04 Sep 2019   Prob (F-statistic):               0.00
# Time:                        16:21:45   Log-Likelihood:                -16155.
# No. Observations:                1349   AIC:                         3.233e+04
# Df Residuals:                    1341   BIC:                         3.237e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1.221e+06   1.38e+05     -8.862      0.000   -1.49e+06   -9.51e+05
# overallqual   2.158e+04   1272.381     16.957      0.000    1.91e+04    2.41e+04
# grlivarea       52.9685      3.267     16.211      0.000      46.559      59.378
# garagecars    1.697e+04   2276.687      7.452      0.000    1.25e+04    2.14e+04
# firstflrsf      32.2042      3.397      9.481      0.000      25.541      38.868
# fullbath     -1.091e+04   2846.004     -3.833      0.000   -1.65e+04   -5325.320
# yearbuilt      298.7273     53.722      5.561      0.000     193.338     404.116
# yearremodadd   277.2474     70.053      3.958      0.000     139.822     414.673
# ==============================================================================
# Omnibus:                      392.557   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37674.806
# Skew:                          -0.218   Prob(JB):                         0.00
# Kurtosis:                      28.886   Cond. No.                     4.49e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# - All features are statistically significant

# %% [markdown]
# ### Exclude the insignificant features from your model. Did anything change?
#
# - N/A

# %% [markdown]
# ## Interpret the statistically significant coefficients by quantifying their relations with the house prices. Which features have a more prominent effect on house prices?

# %%
pd.options.display.float_format = '{:,.2f}'.format # display customization

results.params
# Out:
# const          -1,221,267.08
# overallqual        21,576.34
# grlivarea              52.97
# garagecars         16,966.08
# firstflrsf             32.20
# fullbath          -10,908.43
# yearbuilt             298.73
# yearremodadd          277.25
# dtype: float64

# %% [markdown]
# - Overall quality and number of garages seem to add the most value to a house price. On the other hand, it seems that an extra full bath can lead to a decrease of, approximately, $11,000 to the house value

# %% [markdown]
# ## Do the results sound reasonable to you? If not, try to explain the potential reasons
#
# - It is reasonable that overall quality is a major factor is house sale price. An old house that is in good overall quality would sell for more than a newer house that requires renovations.
# - Size of garage in car space is the second most influential factor and it's the only feature that could be related to overall property size, besides living area, in the model. Therefore, it is resonable that an increase in garage space, i.e. property square area, would lead to a significant increase in house sale price.
# - On the other hand, having an extra full bathroom should increase house price. It is possible that more full bathrooms could be undesires in houses with small spaces. Since this feature only have 4 possible values (0-4), it could be converted to a dummy variable.

# %%
plt.figure(figsize=(10,10))
sns.distplot(houseprice_df.fullbath, kde=False)
plt.title('Number of full above ground bathrooms', size=26)
plt.xlabel('Full bathrooms', size=26)
plt.show()
